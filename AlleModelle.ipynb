# %% [markdown]
# # Klassifikations Pipeline LGBM

# %%
# --- TEIL 0: Bibliotheken importieren und Setup ---
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import gc
import io

# Spezialisierte Bibliotheken
import pastas as ps                                      # Für hydrologische Zeitreihenanalyse, speziell für SGI-Berechnung
import pyarrow.dataset as ds                             # Zum effizienten Laden von Parquet-Dateien
import lightgbm as lgb                                   # Das LightGBM-Modell, ein Gradient Boosting Framework
import shap                                              # Für die Modell-Interpretation (SHapley Additive exPlanations)
from statsmodels.tsa.seasonal import STL                 # Für die saisonale Zerlegung von Zeitreihen
import optuna

# Wichtige Werkzeuge von Scikit-learn
from sklearn.model_selection import GridSearchCV         # Zur automatischen Suche der besten Hyperparameter
from sklearn.pipeline import Pipeline                    # Um mehrere Verarbeitungsschritte zu einem Modell zu verketten
from sklearn.preprocessing import StandardScaler         # Zur Skalierung numerischer Features
from sklearn.impute import SimpleImputer                 # Zum Füllen von fehlenden Werten
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay # Zur Evaluation des Modells
from sklearn.metrics import f1_score
from sklearn.model_selection import cross_val_score

# Helfer-Bibliotheken
from tqdm import tqdm                                    # Für schöne Fortschrittsbalken bei langen Schleifen
from contextlib import redirect_stdout                   # Um störende Ausgaben von Bibliotheken zu unterdrücken

# --- Konfiguration ---
# Loglevel von 'pastas' reduzieren, um die Konsole sauber zu halten
ps.set_log_level("ERROR")
print("Starte Skript: LGBM-Klassifikations-Pipeline")

# --- Definition der Features ---
# Hier werden die Spaltennamen für verschiedene Feature-Typen zentral definiert.
STATIC_CATEGORICAL_FEATURES = ["main_landuse"]
STATIC_NUMERICAL_FEATURES = ["ground_elevation_m_asl", "topographic_slope_degrees"]
DYNAMIC_NUMERICAL_FEATURES_RAW = [
    "groundwater_level_m_asl", "precipitation_gpcc_mm_year-1",
    "potential_evapotranspiration_era5_mm_year-1", "air_temperature_°C", "snow_depth_m",
    "ndvi_ratio", "lai_low_vegetation_ratio", "lai_high_vegetation_ratio",
    "withdrawal_industrial_m3_year-1", "withdrawal_domestic_m3_year-1"
]

# --- TEIL 1 & 2: DATEN LADEN UND FEATURE ENGINEERING ---
print("\n" + "="*80); print(" TEIL 1 & 2: DATEN LADEN UND FEATURE ENGINEERING"); print("="*80)

# --- Schritt 1.1: Statische Attribute laden und filtern ---
print("1.1 Lade statische Attribute und filtere relevante Stationen...")
path_attributes = "C:/MLmitPython/ML-Python/Daten/grow_attributes.parquet"
path_timeseries = "C:/MLmitPython/ML-Python/Daten/grow_timeseries.parquet"
try:
    attr_df_full = pd.read_parquet(path_attributes)
except FileNotFoundError: raise

# Filtere die Attribute nach den gewünschten Kriterien (Tschechien, lange Zeitreihen, keine Lücken etc.)
attr_filtered_df = attr_df_full[(attr_df_full["country"] == "CZE") & (attr_df_full["length_years"] >= 30) & (attr_df_full["gap_fraction"] == 0.0) & (pd.to_datetime(attr_df_full["ending_date"]) >= pd.Timestamp("2023-12-01"))]
if attr_filtered_df.empty: raise ValueError("Keine passende Zeitreihe für CZ für ML gefunden.")
cz_ids_for_ml = attr_filtered_df["GROW_ID"].dropna().unique().tolist()
print(f"--> {len(cz_ids_for_ml)} relevante Stationen für die Analyse gefunden.")

# --- Schritt 1.2: Dynamische Zeitreihen laden ---
print("\n1.2 Lade dynamische Zeitreihen für die ausgewählten Stationen...")
dynamic_feature_columns_to_load = ["GROW_ID", "date"] + DYNAMIC_NUMERICAL_FEATURES_RAW
try:
    # PyArrow wird für schnelles, speichereffizientes Laden der großen Parquet-Datei verwendet
    timeseries_dataset_raw = ds.dataset(path_timeseries, format="parquet")
    available_columns_in_parquet = timeseries_dataset_raw.schema.names
    columns_to_actually_load = [col for col in dynamic_feature_columns_to_load if col in available_columns_in_parquet]
    timeseries_table_raw = timeseries_dataset_raw.to_table(filter=ds.field("GROW_ID").isin(cz_ids_for_ml), columns=columns_to_actually_load)
    raw_ts_df_full = timeseries_table_raw.to_pandas()
except FileNotFoundError: raise
raw_ts_df_full["date"] = pd.to_datetime(raw_ts_df_full["date"])
print("--> Zeitreihen erfolgreich geladen.")

# --- Schritt 1.3: Erste Feature-Anpassungen ---
print("\n1.3 Berechne monatliche Features aus jährlichen Werten...")
if "precipitation_gpcc_mm_year-1" in raw_ts_df_full.columns: raw_ts_df_full["precipitation_gpcc_mm_month-1"] = (raw_ts_df_full["precipitation_gpcc_mm_year-1"] / 12)
if "potential_evapotranspiration_era5_mm_year-1" in raw_ts_df_full.columns: raw_ts_df_full["potential_evapotranspiration_era5_mm_month-1"] = (raw_ts_df_full["potential_evapotranspiration_era5_mm_year-1"] / 12)

# Gruppiere die Zeitreihen nach ihrer ID für die Einzelverarbeitung
grouped_ts_data = raw_ts_df_full.set_index('date').groupby('GROW_ID'); del raw_ts_df_full; gc.collect()


# --- Schritt 1.4: Haupt-Feature-Engineering pro Station ---
print("\n1.4 Führe SGI-Berechnung und Feature-Engineering pro Station durch...")
# Definiere eine Funktion, die alle Schritte für eine einzelne Station durchführt
def process_grow_id_data(grow_id_data):
    # Resample Grundwasserstand auf monatliche Werte
    gwl_series_monthly = grow_id_data["groundwater_level_m_asl"].dropna().resample('MS').mean()
    if gwl_series_monthly.empty or len(gwl_series_monthly.dropna()) < 120: return None
    
    # Berechne den Standardized Groundwater Index (SGI) mit der 'pastas'-Bibliothek
    try:
        with redirect_stdout(io.StringIO()): # Unterdrückt Konsolenausgaben von pastas
            sgi_observed_monthly = ps.stats.sgi(gwl_series_monthly)
        if sgi_observed_monthly.empty or sgi_observed_monthly.isnull().all(): return None
    except Exception: return None
    
    # Zerlege die SGI-Zeitreihe in Trend, Saison und Residuum (Rest)
    sgi_trend, sgi_seasonal, sgi_resid = (pd.Series(dtype=np.float32), pd.Series(dtype=np.float32), pd.Series(dtype=np.float32))
    sgi_for_stl = sgi_observed_monthly.dropna()
    if len(sgi_for_stl) >= 25: # STL benötigt eine minimale Anzahl an Datenpunkten
        try:
            stl = STL(sgi_for_stl, period=12, robust=True); res_stl = stl.fit()
            sgi_trend, sgi_seasonal, sgi_resid = (res_stl.trend, res_stl.seasonal, res_stl.resid)
        except Exception: pass
        
    # Sammle alle berechneten und originalen Features in einem Dictionary
    monthly_features_dict = {'sgi_label': sgi_observed_monthly, 'sgi_trend': sgi_trend, 'sgi_seasonal': sgi_seasonal, 'sgi_resid': sgi_resid}
    dynamic_map = {"precipitation_gpcc_mm_month-1": "precipitation_monthly", "potential_evapotranspiration_era5_mm_month-1": "evapotranspiration_monthly", "air_temperature_°C": "air_temperature_monthly", "snow_depth_m": "snow_depth_monthly", "ndvi_ratio": "ndvi_monthly", "lai_low_vegetation_ratio": "lai_low_veg_monthly", "lai_high_vegetation_ratio": "lai_high_veg_monthly"}
    for orig, target in dynamic_map.items(): monthly_features_dict[target] = grow_id_data[orig].dropna().resample('MS').mean().reindex(sgi_observed_monthly.index) if orig in grow_id_data.columns else pd.Series(index=sgi_observed_monthly.index, dtype=np.float32)
    yearly_map = {"withdrawal_industrial_m3_year-1": "withdrawal_industrial_monthly", "withdrawal_domestic_m3_year-1": "withdrawal_domestic_monthly"}
    for orig, target in yearly_map.items():
        if orig in grow_id_data.columns:
            series_yearly = grow_id_data[orig].dropna(); series_yearly = series_yearly[~series_yearly.index.duplicated(keep='first')] if not series_yearly.index.is_unique else series_yearly; monthly_features_dict[target] = series_yearly.resample('MS').ffill().reindex(sgi_observed_monthly.index)
        else: monthly_features_dict[target] = pd.Series(index=sgi_observed_monthly.index, dtype=np.float32)
        
    return pd.DataFrame(monthly_features_dict).dropna(subset=['sgi_label'])

# Wende die Funktion auf alle Stations-Gruppen an und zeige einen Fortschrittsbalken
processed_groups = []
for grow_id, group_data in tqdm(grouped_ts_data, desc="SGI-Berechnung & Dekomposition"):
    processed_df = process_grow_id_data(group_data)
    if processed_df is not None and not processed_df.empty: processed_df['GROW_ID'] = grow_id; processed_groups.append(processed_df)
if not processed_groups: raise ValueError("Keine Daten für ML-Modell nach Verarbeitung.")

# --- Schritt 1.5: Finale Datenzusammenführung und Feature-Erstellung ---
print("\n1.5 Führe dynamische und statische Features zusammen...")
df_ml_input_dynamic = pd.concat(processed_groups); del processed_groups; gc.collect()
static_features_to_select = ["GROW_ID"] + STATIC_NUMERICAL_FEATURES + STATIC_CATEGORICAL_FEATURES
static_features_to_select = [col for col in static_features_to_select if col in attr_df_full.columns]
attr_df_ml_static = attr_df_full[attr_df_full['GROW_ID'].isin(cz_ids_for_ml)][static_features_to_select].copy().drop_duplicates(subset=['GROW_ID'], keep='first')
df_ml_input_dynamic.reset_index(inplace=True)
df_ml_input = pd.merge(df_ml_input_dynamic, attr_df_ml_static, on="GROW_ID", how="left").set_index('date')
del df_ml_input_dynamic, attr_df_ml_static, attr_df_full; gc.collect()
df_ml_processed = df_ml_input.copy(); del df_ml_input; gc.collect()

print("\n1.6 Erstelle zeitversetzte (Lag) Features und Zielvariable...")
# Erstelle Lag-Features für die SGI-Komponenten (Werte von vor 1, 3, 6, 12 Monaten)
for lag_col_base in ['sgi_label', 'sgi_trend', 'sgi_seasonal', 'sgi_resid']:
    if lag_col_base in df_ml_processed.columns:
        for lag_val in [1, 3, 6, 12]: df_ml_processed[f'{lag_col_base}_lag_{lag_val}M'] = df_ml_processed.groupby('GROW_ID')[lag_col_base].shift(lag_val)

df_ml_processed['month_num'] = df_ml_processed.index.month.astype(np.int8)
df_ml_processed['year'] = df_ml_processed.index.year.astype(np.int32)

# Erstelle die Zielvariable: der SGI-Wert 6 Monate in der Zukunft
VORHERSAGE_HORIZONT_MONATE = 6
sgi_target_col_continuous = f'sgi_target_{VORHERSAGE_HORIZONT_MONATE}M_future'
df_ml_processed[sgi_target_col_continuous] = df_ml_processed.groupby('GROW_ID')['sgi_label'].shift(-VORHERSAGE_HORIZONT_MONATE)

# --- Schritt 1.7: Zielvariable in Klassen umwandeln und Features vorbereiten ---
print("\n1.7 Wandle Zielvariable in Klassen um und kodiere kategorische Features...")
def sgi_to_drought_class(z_score):
    if pd.isna(z_score): return None
    if z_score > -0.84: return 'Normal'
    if -1.50 <= z_score <= -0.84: return 'Mild_Moderate'
    if -2.00 <= z_score <= -1.51: return 'Severe'
    return 'Extreme'
df_ml_processed['drought_class_str'] = df_ml_processed[sgi_target_col_continuous].apply(sgi_to_drought_class)
class_mapping = {'Normal': 0, 'Mild_Moderate': 1, 'Severe': 2, 'Extreme': 3}
df_ml_processed['drought_class_target'] = df_ml_processed['drought_class_str'].map(class_mapping).astype('Int64')
label_column_ml = 'drought_class_target'

# Definiere die zu kodierenden Spalten dynamisch, basierend auf dem, was wirklich im DataFrame ist
print("\n1.7.1 Kodierung der kategorischen Features...")
categorical_cols_to_encode = [col for col in STATIC_CATEGORICAL_FEATURES if col in df_ml_processed.columns]
if 'month_num' in df_ml_processed.columns:
    categorical_cols_to_encode.append('month_num')

print(f"--> Folgende kategorische Spalten werden kodiert: {categorical_cols_to_encode}")

# Die Schleife bleibt gleich, verarbeitet aber nur existierende Spalten
dummy_encoded_cols_list = []
for col_to_encode in categorical_cols_to_encode:
    print(f"    - Kodiere '{col_to_encode}'...")
    dummies = pd.get_dummies(df_ml_processed[col_to_encode], prefix=col_to_encode, dummy_na=False, dtype=np.int8)
    df_ml_processed = pd.concat([df_ml_processed, dummies], axis=1)
    df_ml_processed.drop(columns=[col_to_encode], inplace=True)
    dummy_encoded_cols_list.extend(dummies.columns.tolist())

# --- Schritt 1.8: Finale Datenbereinigung ---
print("\n1.8 Bereinige finale Datensätze...")
# Fülle verbleibende Lücken in numerischen Spalten mit dem Median
numerical_static_cols_for_imputation = [col for col in STATIC_NUMERICAL_FEATURES if col in df_ml_processed.columns]
if numerical_static_cols_for_imputation:
    df_ml_processed[numerical_static_cols_for_imputation] = SimpleImputer(strategy='median').fit_transform(df_ml_processed[numerical_static_cols_for_imputation])

# Definiere die finale Liste aller Features für das Modell
base_features_ml = ["precipitation_monthly", "evapotranspiration_monthly", "air_temperature_monthly", "snow_depth_monthly", "ndvi_monthly", "lai_low_veg_monthly", "lai_high_veg_monthly", "withdrawal_industrial_monthly", "withdrawal_domestic_monthly"]
lag_features_ml = [col for col in df_ml_processed.columns if '_lag_' in col]
current_sgi_features = ['sgi_label', 'sgi_trend', 'sgi_seasonal', 'sgi_resid']
features_columns_ml = list(set([col for col in base_features_ml if col in df_ml_processed.columns] + lag_features_ml + current_sgi_features + numerical_static_cols_for_imputation + dummy_encoded_cols_list))
# +++ DIESE ZEILE BITTE EINFÜGEN +++
columns_to_check_for_dropna_smart = ['sgi_label_lag_1M', 'precipitation_monthly']
# Entferne Zeilen, in denen wichtige Features oder das Label fehlen
df_ml_processed.dropna(subset=[label_column_ml] + [col for col in columns_to_check_for_dropna_smart if col in df_ml_processed.columns], inplace=True)
df_ml_processed[label_column_ml] = df_ml_processed[label_column_ml].astype(int)

# Finale Aufteilung in X (Features) und y (Zielvariable)
X_all_features_raw = df_ml_processed[features_columns_ml].copy()
y_all_labels = df_ml_processed[label_column_ml].copy()
X_meta_for_split = df_ml_processed[['GROW_ID', 'year']].copy()
del df_ml_processed; gc.collect()
print("\n[SUCCESS] Teil 1 & 2 abgeschlossen.")


# --- TEIL 3: MODELLTRAINING & EVALUATION ---
print("\n" + "="*80); print(" TEIL 3: MODELLTRAINING & EVALUATION"); print("="*80)

# --- Schritt 3.1: Zeitbasierter Train-Validation-Test Split ---
temp_year_series = X_meta_for_split['year']
unique_years_ml = np.sort(temp_year_series.unique())
split_year_1 = int(np.percentile(unique_years_ml, 80))
split_year_2 = int(np.percentile(unique_years_ml, 90))
print(f"--> Erstelle zeitbasierten 80/10/10 Split:")
print(f"      - Trainingsdaten: Jahre < {split_year_1} (80%)")
print(f"      - Validierungsdaten: Jahre >= {split_year_1} und < {split_year_2} (10%)")
print(f"      - Testdaten: Jahre >= {split_year_2} (10%)")
train_mask = temp_year_series < split_year_1
val_mask = (temp_year_series >= split_year_1) & (temp_year_series < split_year_2)
test_mask = temp_year_series >= split_year_2
X_train_raw, X_val_raw, X_test_raw = X_all_features_raw[train_mask], X_all_features_raw[val_mask], X_all_features_raw[test_mask]
y_train, y_val, y_test = y_all_labels[train_mask], y_all_labels[val_mask], y_all_labels[test_mask]
print(f"\nGröße der Datensätze:")
print(f"      - Training:   {X_train_raw.shape[0]} Zeilen")
print(f"      - Validation: {X_val_raw.shape[0]} Zeilen")
print(f"      - Test:       {X_test_raw.shape[0]} Zeilen")
del X_all_features_raw, y_all_labels, X_meta_for_split; gc.collect()

# --- Schritt 3.2: Finale Feature-Übersicht ---
print("\n" + "-"*80)
features_in_model = sorted(X_train_raw.columns.tolist())
print(f"--> Folgende {len(features_in_model)} Features werden für das Modell verwendet:")
print("-" * 80)
max_len = max(len(f) for f in features_in_model) + 2
num_columns = 4
for i in range(0, len(features_in_model), num_columns):
    row = [f"{feat:<{max_len}}" for feat in features_in_model[i:i+num_columns]]
    print("".join(row))
print("-" * 80)

# --- Schritt 3.3: OPTIMALES HYPERPARAMETER-TUNING FÜR LGBM MIT KREUZVALIDIERUNG 
print("\n--> Starte optimales Modell-Tuning (LGBM) mit Optuna, CV und nativer 'is_unbalance=True' Einstellung...")

# Definiere die "Objective"-Funktion mit Kreuzvalidierung
def objective(trial):
    # Definiere den Suchraum für die LightGBM-Hyperparameter
    param = {
        'objective': 'multiclass',
        'num_class': len(class_mapping),
        'metric': 'multi_logloss',
        'random_state': 42,
        'verbosity': -1,
        'is_unbalance': True,  # +++ GEÄNDERT: Wir nutzen jetzt die eingebaute Stärke von LGBM +++
        'n_estimators': trial.suggest_int('n_estimators', 200, 1000, step=50),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2, log=True),
        'num_leaves': trial.suggest_int('num_leaves', 20, 80),
        'max_depth': trial.suggest_int('max_depth', 5, 15),
        'min_child_samples': trial.suggest_int('min_child_samples', 10, 100),
        'subsample': trial.suggest_float('subsample', 0.6, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0)
    }

    # Erstelle eine vollständige Pipeline INNTERHALB des Trials
    pipeline_cv = Pipeline(steps=[
        ('imputer', SimpleImputer(strategy='mean')),
        ('scaler', StandardScaler()),
        ('classifier', lgb.LGBMClassifier(**param))
    ])

    # Führe die Kreuzvalidierung durch
    scores = cross_val_score(
        pipeline_cv,
        X=X_train_raw,
        y=y_train,
        scoring='f1_weighted',
        cv=5,
        n_jobs=-1
    )
    
    # Gib den durchschnittlichen Score zurück
    return scores.mean()

# Der Optuna-Loop
study = optuna.create_study(direction='maximize')
print(f"\nStarte Optuna-Suche für LGBM mit 50 Trials und 5-facher CV.")
study.optimize(objective, n_trials=50, show_progress_bar=True)

# Das Erstellen der finalen Pipeline
print("\nOptimierung abgeschlossen!")
print(f"Bester cross-validierter F1-Score: {study.best_value:.4f}")
print("Beste gefundene Hyperparameter für LGBM:")
print(study.best_params)

print("\n--> Erstelle finale Pipeline mit den besten Hyperparametern...")
best_params_lgbm = study.best_params
best_model_pipeline = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler()),
    ('classifier', lgb.LGBMClassifier(
        objective='multiclass',
        num_class=len(class_mapping),
        is_unbalance=True, # +++ GEÄNDERT: Auch im finalen Modell nutzen wir die native Einstellung +++
        random_state=42,
        **best_params_lgbm
    ))
])

print("Trainiere das finale LGBM-Modell auf den Trainingsdaten...")
# --- ENTFERNT --- Die sample_weights werden beim finalen fit nicht mehr übergeben
best_model_pipeline.fit(X_train_raw, y_train)
print("Finales Modell ist trainiert und bereit für die Evaluation.")


# --- Schritt 3.4: Evaluation des besten Modells ---
def evaluate_and_plot(X_data, y_data, dataset_name, model_pipeline):
    """Eine Helfer-Funktion zur standardisierten Evaluation und Visualisierung."""
    if X_data.empty or y_data.empty:
        print(f"\n{dataset_name}-Datensatz ist leer. Evaluation wird übersprungen.")
        return None, None
    print("\n" + "-"*80); print(f" EVALUATION AUF {dataset_name.upper()}-DATEN"); print("-" * 80)
    
    # Mache Vorhersagen
    y_pred = model_pipeline.predict(X_data)
    y_pred_proba = model_pipeline.predict_proba(X_data)
    
    # Gebe den Klassifikations-Report aus
    class_names = list(class_mapping.keys())
    print("\nKlassifikations-Metriken:")
    print(classification_report(y_data, y_pred, labels=range(len(class_names)), target_names=class_names, zero_division=0))
    
    # Plotte die Konfusionsmatrix
    cm = confusion_matrix(y_data, y_pred, labels=range(len(class_names)))
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
    fig, ax = plt.subplots(figsize=(10, 8)); disp.plot(cmap=plt.cm.Blues, ax=ax, xticks_rotation='vertical'); ax.set_title(f'Klassifikationsmatrix für {dataset_name}'); plt.tight_layout(); plt.show()
    
    return y_pred, y_pred_proba

# Führe die Evaluation für Validierungs- und Test-Set durch
y_val_pred, y_val_pred_proba = evaluate_and_plot(X_val_raw, y_val, "Validation", best_model_pipeline)
y_test_pred, y_test_pred_proba = evaluate_and_plot(X_test_raw, y_test, "Test", best_model_pipeline)


# +++ ÜBERARBEITETER TEIL 3C: UMFASSENDE MODELLINTERPRETATION +++
print("\n" + "="*80); print(" TEIL 3C: MODELLINTERPRETATION"); print("="*80)
try:
    if not X_val_raw.empty:
        # Schritt 1: Trainierten Classifier aus der Pipeline extrahieren
        lgbm_classifier = best_model_pipeline.named_steps['classifier']
        
        # --- Klassische Feature Importance direkt vom Modell ---
        print("\n--> LightGBM Feature Importance (nach 'gain'):")
        feature_importance_df = pd.DataFrame({
            'feature': X_train_raw.columns,
            'importance': lgbm_classifier.feature_importances_
        }).sort_values('importance', ascending=False).head(20)
        print(feature_importance_df)

        # --- SHAP-Analyse ---
        print("\n--> Bereite Daten für SHAP-Analyse vor (Transformation durch Pipeline)...")
        X_val_transformed = best_model_pipeline.named_steps['imputer'].transform(X_val_raw)
        X_val_transformed = best_model_pipeline.named_steps['scaler'].transform(X_val_transformed)
        X_val_transformed_df = pd.DataFrame(X_val_transformed, columns=X_val_raw.columns, index=X_val_raw.index)

        print("\n--> Berechne SHAP-Werte...")
        explainer = shap.TreeExplainer(lgbm_classifier)
        shap_values = explainer.shap_values(X_val_transformed_df)
        
        # --- DEBUGGING-AUSGABEN BEIBEHALTEN ---
        print(f"DEBUG: SHAP-Werte-Typ: {type(shap_values)}")
        if isinstance(shap_values, list):
            print(f"DEBUG: SHAP-Werte-ist-Liste: True, Anzahl der Elemente: {len(shap_values)}")
            if len(shap_values) > 0:
                print(f"DEBUG: Typ des ersten SHAP-Array-Elements: {type(shap_values[0])}")
                if hasattr(shap_values[0], 'shape'):
                    print(f"DEBUG: Shape des ersten SHAP-Array-Elements: {shap_values[0].shape}")
        else:
            print(f"DEBUG: SHAP-Werte-ist-Liste: False (Ist direkt ein Array o.ä.)")
            if hasattr(shap_values, 'shape'):
                print(f"DEBUG: Shape des SHAP-Values-Arrays: {shap_values.shape}")
        # --- ENDE DEBUGGING-AUSGABEN ---

        MAX_SHAP_FEATURES = 40
        
        # --- Globaler SHAP Feature Importance Plot (Bar-Diagramm) ---
        print("\n--> Erstelle SHAP Feature Importance Plot (global)...")
        
        if isinstance(shap_values, np.ndarray) and shap_values.ndim == 3: # Dies ist der Fall, der jetzt eintritt!
            print("INFO: SHAP-Werte sind ein 3D NumPy-Array. Aggregiere für globalen Bar-Plot.")
            # Korrektur hier: Nur Mittelung über die Klassen (Achse 2), um ein 2D-Array (Samples, Features) zu erhalten.
            # shap_values_for_global_plot hat jetzt die Form (Samples, Features)
            shap_values_for_global_plot = np.mean(np.abs(shap_values), axis=2) 
            
            # Jetzt plotten wir mit diesem 2D-Array
            shap.summary_plot(shap_values_for_global_plot, X_val_transformed_df, plot_type="bar", max_display=MAX_SHAP_FEATURES, show=False)
            plt.title("SHAP Feature Importance (Globaler Durchschnitt über alle Klassen)")
            plt.tight_layout()
            plt.show()
            
            # --- SHAP Beeswarm Plots (Detailansicht) für jede Klasse ---
            print("\n--> Erstelle SHAP Beeswarm Plots (Detailansicht) für jede Klasse...")
            for i, class_name in enumerate(list(class_mapping.keys())):
                print(f"    - Erstelle Beeswarm Plot für Klasse: '{class_name}' (Index {i})")
                plt.figure(figsize=(12, 8))
                # shap_values[:, :, i] extrahiert die SHAP-Werte für die i-te Klasse für alle Samples und Features (dies ist bereits ein 2D-Array)
                shap.summary_plot(shap_values[:, :, i], X_val_transformed_df, max_display=MAX_SHAP_FEATURES, feature_names=X_val_transformed_df.columns, show=False)
                plt.title(f"SHAP-Werte für Klasse: '{class_name}'")
                plt.tight_layout()
                plt.show()
                
        elif isinstance(shap_values, list) and len(shap_values) > 1: # Fall für Liste von Arrays (alternative SHAP-Ausgabe)
            print("INFO: SHAP-Werte sind Liste für Multiklasse. Aggregiere für globalen Bar-Plot.")
            # Korrektur hier: Wandle Liste in Array um und mittel nur über die Klassenachse
            shap_values_for_global_plot = np.mean(np.abs(np.array(shap_values)), axis=0) # Hier ist axis=0 korrekt, wenn es eine Liste von 2D-Arrays ist, denn dann ist der erste Index die Klasse
            
            shap.summary_plot(shap_values_for_global_plot, X_val_transformed_df, plot_type="bar", max_display=MAX_SHAP_FEATURES, show=False)
            plt.title("SHAP Feature Importance (Globaler Durchschnitt über alle Klassen)")
            plt.tight_layout()
            plt.show()
            
            # Beeswarm Plots pro Klasse aus der Liste
            print("\n--> Erstelle SHAP Beeswarm Plots (Detailansicht) für jede Klasse...")
            if len(shap_values) == len(class_mapping):
                for i, class_name in enumerate(list(class_mapping.keys())):
                    print(f"    - Erstelle Beeswarm Plot für Klasse: '{class_name}' (Index {i})")
                    plt.figure(figsize=(12, 8))
                    shap.summary_plot(shap_values[i], X_val_transformed_df, max_display=MAX_SHAP_FEATURES, feature_names=X_val_transformed_df.columns, show=False)
                    plt.title(f"SHAP-Werte für Klasse: '{class_name}'")
                    plt.tight_layout()
                    plt.show()
            else:
                print(f"WARNUNG: Anzahl der SHAP-Werte-Listen ({len(shap_values)}) stimmt nicht mit der Anzahl der Klassen ({len(class_mapping)}) überein. Überspringe Beeswarm Plots pro Klasse.")
                
        else: # Dies wird ausgeführt, wenn shap_values KEINE Liste ist ODER eine Liste mit nur einem Element (was auf ein binäres Problem hindeutet)
            print("INFO: SHAP-Werte sind kein Multiklassen-Format (oder nur eine Klasse). Erstelle einen einzelnen globalen Beeswarm/Bar-Plot.")
            # Für den globalen Plot bei nur einer Klasse, Beeswarm ist oft aussagekräftiger
            shap.summary_plot(shap_values, X_val_transformed_df, max_display=MAX_SHAP_FEATURES, feature_names=X_val_transformed_df.columns, show=False)
            plt.title("SHAP-Werte (Gesamt / Binäre Klassifikation)")
            plt.tight_layout()
            plt.show()
            print("WARNUNG: Keine Beeswarm Plots pro Klasse möglich, da SHAP-Werte nicht im Multiklassen-Listenformat vorliegen.")
            
    else:
        print("Validierungsdaten sind leer, SHAP-Analyse wird übersprungen.")
except Exception as e:
    print(f"Fehler bei der SHAP-Analyse: {e}")
    import traceback
    traceback.print_exc()

print("\n[SUCCESS] Teil 3 abgeschlossen.")

# --- TEIL 4: SPEICHERN DER ERGEBNISSE ---
print("\n" + "="*80); print(" TEIL 4: SPEICHERN DER ERGEBNISSE"); print("=" * 80)
if not X_test_raw.empty:
    # Erstelle ein finales DataFrame mit den Test-Features, den wahren Werten,
    # den Vorhersagen und den Vorhersage-Wahrscheinlichkeiten.
    test_results_df = X_test_raw.copy()
    test_results_df[label_column_ml] = y_test
    test_results_df['prediction'] = y_test_pred
    proba_df = pd.DataFrame(y_test_pred_proba, columns=[f'prediction_proba_{cls}' for cls in class_mapping.keys()], index=test_results_df.index)
    test_results_df = pd.concat([test_results_df, proba_df], axis=1)
    
    # Speichere das DataFrame als CSV-Datei
    test_results_df.to_csv("test_data_final_classification.csv", index=True)
    print(f"--> Testdaten mit Vorhersagen und Wahrscheinlichkeiten gespeichert: test_data_final_classification.csv")
else:
    print("--> Testdaten sind leer, keine Speicherung.")

print("\nSkript vollständig abgeschlossen.")
# Out:
# Starte Skript: LGBM-Klassifikations-Pipeline
#
# ================================================================================
#  TEIL 1 & 2: DATEN LADEN UND FEATURE ENGINEERING
# ================================================================================
# 1.1 Lade statische Attribute und filtere relevante Stationen...
# --> 264 relevante Stationen für die Analyse gefunden.
#
# 1.2 Lade dynamische Zeitreihen für die ausgewählten Stationen...
# --> Zeitreihen erfolgreich geladen.
#
# 1.3 Berechne monatliche Features aus jährlichen Werten...
#
# 1.4 Führe SGI-Berechnung und Feature-Engineering pro Station durch...
# SGI-Berechnung & Dekomposition: 100%|██████████| 264/264 [00:47<00:00,  5.57it/s]
# 1.5 Führe dynamische und statische Features zusammen...
#
# 1.6 Erstelle zeitversetzte (Lag) Features und Zielvariable...
#
# 1.7 Wandle Zielvariable in Klassen um und kodiere kategorische Features...
#
# 1.7.1 Kodierung der kategorischen Features...
# --> Folgende kategorische Spalten werden kodiert: ['main_landuse', 'month_num']
#     - Kodiere 'main_landuse'...
#     - Kodiere 'month_num'...
#
# 1.8 Bereinige finale Datensätze...
#
# [SUCCESS] Teil 1 & 2 abgeschlossen.
#
# ================================================================================
#  TEIL 3: MODELLTRAINING & EVALUATION
# ================================================================================
# --> Erstelle zeitbasierten 80/10/10 Split:
#       - Trainingsdaten: Jahre < 2008 (80%)
#       - Validierungsdaten: Jahre >= 2008 und < 2014 (10%)
#       - Testdaten: Jahre >= 2014 (10%)
# [I 2025-06-30 12:49:23,561] A new study created in memory with name: no-name-37592f03-ba44-4b91-aa38-984ab56d0b8e
# Größe der Datensätze:
#       - Training:   129036 Zeilen
#       - Validation: 19008 Zeilen
#       - Test:       22176 Zeilen
#
# --------------------------------------------------------------------------------
# --> Folgende 45 Features werden für das Modell verwendet:
# --------------------------------------------------------------------------------
# air_temperature_monthly                      evapotranspiration_monthly                   ground_elevation_m_asl                       lai_high_veg_monthly
# lai_low_veg_monthly                          main_landuse_cropland_rainfed                main_landuse_forests_and_natural_vegetation  month_num_1
# month_num_10                                 month_num_11                                 month_num_12                                 month_num_2
# month_num_3                                  month_num_4                                  month_num_5                                  month_num_6
# month_num_7                                  month_num_8                                  month_num_9                                  ndvi_monthly
# precipitation_monthly                        sgi_label                                    sgi_label_lag_12M                            sgi_label_lag_1M
# sgi_label_lag_3M                             sgi_label_lag_6M                             sgi_resid                                    sgi_resid_lag_12M
# sgi_resid_lag_1M                             sgi_resid_lag_3M                             sgi_resid_lag_6M                             sgi_seasonal
# sgi_seasonal_lag_12M                         sgi_seasonal_lag_1M                          sgi_seasonal_lag_3M                          sgi_seasonal_lag_6M
# sgi_trend                                    sgi_trend_lag_12M                            sgi_trend_lag_1M                             sgi_trend_lag_3M
# sgi_trend_lag_6M                             snow_depth_monthly                           topographic_slope_degrees                    withdrawal_domestic_monthly
# withdrawal_industrial_monthly
# --------------------------------------------------------------------------------
#
# --> Starte optimales Modell-Tuning (LGBM) mit Optuna, CV und nativer 'is_unbalance=True' Einstellung...
#
# Starte Optuna-Suche für LGBM mit 50 Trials und 5-facher CV.
# Best trial: 0. Best value: 0.853548:   2%|▏         | 1/50 [01:05<53:52, 65.97s/it]
# [I 2025-06-30 12:50:29,528] Trial 0 finished with value: 0.8535481665499495 and parameters: {'n_estimators': 450, 'learning_rate': 0.012051108903708103, 'num_leaves': 37, 'max_depth': 10, 'min_child_samples': 42, 'subsample': 0.6564216754783567, 'colsample_bytree': 0.6987632377775364}. Best is trial 0 with value: 0.8535481665499495.
# Best trial: 1. Best value: 0.857861:   4%|▍         | 2/50 [04:02<1:44:49, 131.02s/it]
# [I 2025-06-30 12:53:26,080] Trial 1 finished with value: 0.8578610679882839 and parameters: {'n_estimators': 900, 'learning_rate': 0.03043952412906736, 'num_leaves': 72, 'max_depth': 7, 'min_child_samples': 96, 'subsample': 0.6133659669671315, 'colsample_bytree': 0.6151435602640097}. Best is trial 1 with value: 0.8578610679882839.
# Best trial: 1. Best value: 0.857861:   6%|▌         | 3/50 [05:06<1:18:41, 100.45s/it]
# [I 2025-06-30 12:54:30,165] Trial 2 finished with value: 0.8563683064106277 and parameters: {'n_estimators': 450, 'learning_rate': 0.07824444874467186, 'num_leaves': 25, 'max_depth': 8, 'min_child_samples': 18, 'subsample': 0.8976122813448333, 'colsample_bytree': 0.7454093525382284}. Best is trial 1 with value: 0.8578610679882839.
# Best trial: 1. Best value: 0.857861:   8%|▊         | 4/50 [05:39<56:33, 73.77s/it]
# [I 2025-06-30 12:55:03,028] Trial 3 finished with value: 0.8575322076571419 and parameters: {'n_estimators': 200, 'learning_rate': 0.05419515165663386, 'num_leaves': 33, 'max_depth': 9, 'min_child_samples': 97, 'subsample': 0.6124810003836869, 'colsample_bytree': 0.9237383438461919}. Best is trial 1 with value: 0.8578610679882839.
# Best trial: 1. Best value: 0.857861:  10%|█         | 5/50 [07:42<1:08:33, 91.42s/it]
# [I 2025-06-30 12:57:05,743] Trial 4 finished with value: 0.8564305888855032 and parameters: {'n_estimators': 800, 'learning_rate': 0.14407236982865393, 'num_leaves': 52, 'max_depth': 13, 'min_child_samples': 74, 'subsample': 0.7295243611358301, 'colsample_bytree': 0.9192414311894996}. Best is trial 1 with value: 0.8578610679882839.
# Best trial: 1. Best value: 0.857861:  12%|█▏        | 6/50 [09:02<1:04:18, 87.69s/it]
# [I 2025-06-30 12:58:26,184] Trial 5 finished with value: 0.8576011543042423 and parameters: {'n_estimators': 500, 'learning_rate': 0.051856524068416086, 'num_leaves': 47, 'max_depth': 7, 'min_child_samples': 30, 'subsample': 0.8975353610332333, 'colsample_bytree': 0.731825058412402}. Best is trial 1 with value: 0.8578610679882839.
# Best trial: 1. Best value: 0.857861:  14%|█▍        | 7/50 [09:54<54:24, 75.92s/it]
# [I 2025-06-30 12:59:17,878] Trial 6 finished with value: 0.8559517251267439 and parameters: {'n_estimators': 500, 'learning_rate': 0.030318476339332146, 'num_leaves': 20, 'max_depth': 9, 'min_child_samples': 75, 'subsample': 0.9820767218538674, 'colsample_bytree': 0.815452647835914}. Best is trial 1 with value: 0.8578610679882839.
# Best trial: 7. Best value: 0.859114:  16%|█▌        | 8/50 [11:40<59:48, 85.45s/it]
# [I 2025-06-30 13:01:03,739] Trial 7 finished with value: 0.8591135527278106 and parameters: {'n_estimators': 650, 'learning_rate': 0.05905081869860228, 'num_leaves': 48, 'max_depth': 15, 'min_child_samples': 84, 'subsample': 0.9668986451926996, 'colsample_bytree': 0.9452190388270447}. Best is trial 7 with value: 0.8591135527278106.
# Best trial: 7. Best value: 0.859114:  18%|█▊        | 9/50 [14:30<1:16:35, 112.08s/it]
# [I 2025-06-30 13:03:54,383] Trial 8 finished with value: 0.8583831631892214 and parameters: {'n_estimators': 850, 'learning_rate': 0.03741255450967448, 'num_leaves': 62, 'max_depth': 10, 'min_child_samples': 54, 'subsample': 0.9860027875099766, 'colsample_bytree': 0.8695677469815428}. Best is trial 7 with value: 0.8591135527278106.
# Best trial: 7. Best value: 0.859114:  20%|██        | 10/50 [17:04<1:23:15, 124.90s/it]
# [I 2025-06-30 13:06:27,975] Trial 9 finished with value: 0.8551918888618172 and parameters: {'n_estimators': 900, 'learning_rate': 0.1658930900999254, 'num_leaves': 46, 'max_depth': 13, 'min_child_samples': 49, 'subsample': 0.7995549757179102, 'colsample_bytree': 0.9991251785361726}. Best is trial 7 with value: 0.8591135527278106.
# Best trial: 10. Best value: 0.859359:  22%|██▏       | 11/50 [20:08<1:32:56, 143.00s/it]
# [I 2025-06-30 13:09:32,011] Trial 10 finished with value: 0.8593594374320951 and parameters: {'n_estimators': 700, 'learning_rate': 0.013321023018719, 'num_leaves': 80, 'max_depth': 15, 'min_child_samples': 71, 'subsample': 0.8851163876061454, 'colsample_bytree': 0.998576505241079}. Best is trial 10 with value: 0.8593594374320951.
# Best trial: 10. Best value: 0.859359:  24%|██▍       | 12/50 [22:35<1:31:20, 144.22s/it]
# [I 2025-06-30 13:11:59,033] Trial 11 finished with value: 0.8590427849593624 and parameters: {'n_estimators': 700, 'learning_rate': 0.011488559160463032, 'num_leaves': 74, 'max_depth': 15, 'min_child_samples': 75, 'subsample': 0.8874880097092022, 'colsample_bytree': 0.9989669203772094}. Best is trial 10 with value: 0.8593594374320951.
# Best trial: 12. Best value: 0.859603:  26%|██▌       | 13/50 [24:57<1:28:29, 143.50s/it]
# [I 2025-06-30 13:14:20,884] Trial 12 finished with value: 0.8596028929111981 and parameters: {'n_estimators': 650, 'learning_rate': 0.017499651123817385, 'num_leaves': 61, 'max_depth': 14, 'min_child_samples': 68, 'subsample': 0.8348553094142657, 'colsample_bytree': 0.9275266219261293}. Best is trial 12 with value: 0.8596028929111981.
# Best trial: 12. Best value: 0.859603:  28%|██▊       | 14/50 [28:02<1:33:36, 156.00s/it]
# [I 2025-06-30 13:17:25,769] Trial 13 finished with value: 0.8593130231994595 and parameters: {'n_estimators': 1000, 'learning_rate': 0.019870165872522574, 'num_leaves': 79, 'max_depth': 13, 'min_child_samples': 64, 'subsample': 0.8180191250124779, 'colsample_bytree': 0.8635314451089015}. Best is trial 12 with value: 0.8596028929111981.
# Best trial: 12. Best value: 0.859603:  30%|███       | 15/50 [29:19<1:17:13, 132.38s/it]
# [I 2025-06-30 13:18:43,398] Trial 14 finished with value: 0.8552169507320775 and parameters: {'n_estimators': 700, 'learning_rate': 0.01849529218203015, 'num_leaves': 61, 'max_depth': 5, 'min_child_samples': 63, 'subsample': 0.813369618555145, 'colsample_bytree': 0.9572122145297997}. Best is trial 12 with value: 0.8596028929111981.
# Best trial: 12. Best value: 0.859603:  32%|███▏      | 16/50 [30:08<1:00:46, 107.24s/it]
# [I 2025-06-30 13:19:32,260] Trial 15 finished with value: 0.8563412446069835 and parameters: {'n_estimators': 250, 'learning_rate': 0.01816200447243076, 'num_leaves': 66, 'max_depth': 12, 'min_child_samples': 36, 'subsample': 0.7541569340202682, 'colsample_bytree': 0.8841168083867832}. Best is trial 12 with value: 0.8596028929111981.
# Best trial: 12. Best value: 0.859603:  34%|███▍      | 17/50 [32:28<1:04:24, 117.11s/it]
# [I 2025-06-30 13:21:52,337] Trial 16 finished with value: 0.8574776602904345 and parameters: {'n_estimators': 600, 'learning_rate': 0.010298183649184214, 'num_leaves': 58, 'max_depth': 15, 'min_child_samples': 63, 'subsample': 0.8665199373348449, 'colsample_bytree': 0.8052690609203352}. Best is trial 12 with value: 0.8596028929111981.
# Best trial: 12. Best value: 0.859603:  36%|███▌      | 18/50 [33:54<57:22, 107.59s/it]
# [I 2025-06-30 13:23:17,741] Trial 17 finished with value: 0.8585147234649403 and parameters: {'n_estimators': 350, 'learning_rate': 0.015695944525388382, 'num_leaves': 80, 'max_depth': 12, 'min_child_samples': 80, 'subsample': 0.9311959055660747, 'colsample_bytree': 0.9667560561822243}. Best is trial 12 with value: 0.8596028929111981.
# Best trial: 12. Best value: 0.859603:  38%|███▊      | 19/50 [37:30<1:12:30, 140.33s/it]
# [I 2025-06-30 13:26:54,368] Trial 18 finished with value: 0.8584869945736818 and parameters: {'n_estimators': 750, 'learning_rate': 0.026786364786154194, 'num_leaves': 71, 'max_depth': 14, 'min_child_samples': 87, 'subsample': 0.8549621925094376, 'colsample_bytree': 0.903652289348786}. Best is trial 12 with value: 0.8596028929111981.
# Best trial: 12. Best value: 0.859603:  40%|████      | 20/50 [39:56<1:10:54, 141.82s/it]
# [I 2025-06-30 13:29:19,643] Trial 19 finished with value: 0.8587587742051717 and parameters: {'n_estimators': 600, 'learning_rate': 0.014396415779623048, 'num_leaves': 55, 'max_depth': 12, 'min_child_samples': 10, 'subsample': 0.7569947085970913, 'colsample_bytree': 0.8355130298423274}. Best is trial 12 with value: 0.8596028929111981.
# Best trial: 12. Best value: 0.859603:  42%|████▏     | 21/50 [42:11<1:07:34, 139.80s/it]
# [I 2025-06-30 13:31:34,737] Trial 20 finished with value: 0.8594179257928515 and parameters: {'n_estimators': 600, 'learning_rate': 0.023644859885537082, 'num_leaves': 67, 'max_depth': 14, 'min_child_samples': 64, 'subsample': 0.9421228930495423, 'colsample_bytree': 0.7728418262817226}. Best is trial 12 with value: 0.8596028929111981.
# Best trial: 12. Best value: 0.859603:  44%|████▍     | 22/50 [44:07<1:01:56, 132.73s/it]
# [I 2025-06-30 13:33:30,979] Trial 21 finished with value: 0.8592510218823438 and parameters: {'n_estimators': 600, 'learning_rate': 0.02295232031287289, 'num_leaves': 67, 'max_depth': 14, 'min_child_samples': 68, 'subsample': 0.9286989463561226, 'colsample_bytree': 0.773714258515816}. Best is trial 12 with value: 0.8596028929111981.
# Best trial: 12. Best value: 0.859603:  46%|████▌     | 23/50 [45:56<56:34, 125.71s/it]
# [I 2025-06-30 13:35:20,302] Trial 22 finished with value: 0.8580059149907534 and parameters: {'n_estimators': 550, 'learning_rate': 0.01442426507726542, 'num_leaves': 67, 'max_depth': 14, 'min_child_samples': 54, 'subsample': 0.9423500622169677, 'colsample_bytree': 0.6935654176218524}. Best is trial 12 with value: 0.8596028929111981.
# Best trial: 12. Best value: 0.859603:  48%|████▊     | 24/50 [49:02<1:02:14, 143.63s/it]
# [I 2025-06-30 13:38:25,737] Trial 23 finished with value: 0.8580059896291452 and parameters: {'n_estimators': 700, 'learning_rate': 0.025407598117068966, 'num_leaves': 76, 'max_depth': 11, 'min_child_samples': 69, 'subsample': 0.8450580155140415, 'colsample_bytree': 0.6417236974460724}. Best is trial 12 with value: 0.8596028929111981.
# Best trial: 12. Best value: 0.859603:  50%|█████     | 25/50 [51:23<59:33, 142.95s/it]
# [I 2025-06-30 13:40:47,112] Trial 24 finished with value: 0.858342938900107 and parameters: {'n_estimators': 800, 'learning_rate': 0.04169316166744275, 'num_leaves': 63, 'max_depth': 14, 'min_child_samples': 89, 'subsample': 0.9195503259625368, 'colsample_bytree': 0.7752359341403978}. Best is trial 12 with value: 0.8596028929111981.
# Best trial: 12. Best value: 0.859603:  52%|█████▏    | 26/50 [52:39<49:05, 122.73s/it]
# [I 2025-06-30 13:42:02,654] Trial 25 finished with value: 0.8588315875006785 and parameters: {'n_estimators': 400, 'learning_rate': 0.021264193707814925, 'num_leaves': 72, 'max_depth': 15, 'min_child_samples': 45, 'subsample': 0.955904568640697, 'colsample_bytree': 0.8432684975333662}. Best is trial 12 with value: 0.8596028929111981.
# Best trial: 12. Best value: 0.859603:  54%|█████▍    | 27/50 [54:48<47:48, 124.73s/it]
# [I 2025-06-30 13:44:12,061] Trial 26 finished with value: 0.8594303386068554 and parameters: {'n_estimators': 650, 'learning_rate': 0.013901505596754453, 'num_leaves': 57, 'max_depth': 13, 'min_child_samples': 57, 'subsample': 0.8375100597218845, 'colsample_bytree': 0.9764611988231989}. Best is trial 12 with value: 0.8596028929111981.
# Best trial: 12. Best value: 0.859603:  56%|█████▌    | 28/50 [56:07<40:42, 111.00s/it]
# [I 2025-06-30 13:45:31,032] Trial 27 finished with value: 0.8588385072939744 and parameters: {'n_estimators': 550, 'learning_rate': 0.03465352000325773, 'num_leaves': 41, 'max_depth': 11, 'min_child_samples': 61, 'subsample': 0.7067051022599373, 'colsample_bytree': 0.9641927435302475}. Best is trial 12 with value: 0.8596028929111981.
# Best trial: 12. Best value: 0.859603:  58%|█████▊    | 29/50 [57:51<38:09, 109.00s/it]
# [I 2025-06-30 13:47:15,362] Trial 28 finished with value: 0.8588303566931776 and parameters: {'n_estimators': 650, 'learning_rate': 0.01685039515413313, 'num_leaves': 56, 'max_depth': 13, 'min_child_samples': 59, 'subsample': 0.8330927624654917, 'colsample_bytree': 0.8905123196214646}. Best is trial 12 with value: 0.8596028929111981.
# Best trial: 12. Best value: 0.859603:  60%|██████    | 30/50 [59:03<32:38, 97.93s/it]
# [I 2025-06-30 13:48:27,463] Trial 29 finished with value: 0.8502126727049785 and parameters: {'n_estimators': 350, 'learning_rate': 0.011402176406394666, 'num_leaves': 42, 'max_depth': 11, 'min_child_samples': 38, 'subsample': 0.7921318608009265, 'colsample_bytree': 0.6734187673548302}. Best is trial 12 with value: 0.8596028929111981.
# Best trial: 12. Best value: 0.859603:  62%|██████▏   | 31/50 [1:00:31<30:01, 94.82s/it]
# [I 2025-06-30 13:49:55,022] Trial 30 finished with value: 0.8565468415982664 and parameters: {'n_estimators': 500, 'learning_rate': 0.08358713478333146, 'num_leaves': 52, 'max_depth': 14, 'min_child_samples': 52, 'subsample': 0.6742002193069142, 'colsample_bytree': 0.7324874581431553}. Best is trial 12 with value: 0.8596028929111981.
# Best trial: 31. Best value: 0.859746:  64%|██████▍   | 32/50 [1:03:15<34:38, 115.49s/it]
# [I 2025-06-30 13:52:38,753] Trial 31 finished with value: 0.8597460176073124 and parameters: {'n_estimators': 750, 'learning_rate': 0.013275070059726883, 'num_leaves': 68, 'max_depth': 15, 'min_child_samples': 70, 'subsample': 0.8787322489550233, 'colsample_bytree': 0.9901903617907937}. Best is trial 31 with value: 0.8597460176073124.
# Best trial: 31. Best value: 0.859746:  66%|██████▌   | 33/50 [1:06:35<39:55, 140.91s/it]
# [I 2025-06-30 13:55:58,986] Trial 32 finished with value: 0.859104753931387 and parameters: {'n_estimators': 800, 'learning_rate': 0.011892175056878913, 'num_leaves': 59, 'max_depth': 13, 'min_child_samples': 80, 'subsample': 0.7796159827330679, 'colsample_bytree': 0.9260087715459889}. Best is trial 31 with value: 0.8597460176073124.
# Best trial: 31. Best value: 0.859746:  68%|██████▊   | 34/50 [1:09:13<38:57, 146.08s/it]
# [I 2025-06-30 13:58:37,122] Trial 33 finished with value: 0.8595407516469088 and parameters: {'n_estimators': 650, 'learning_rate': 0.015993730432908103, 'num_leaves': 69, 'max_depth': 14, 'min_child_samples': 58, 'subsample': 0.8624135019690787, 'colsample_bytree': 0.9676621706056732}. Best is trial 31 with value: 0.8597460176073124.
# Best trial: 31. Best value: 0.859746:  70%|███████   | 35/50 [1:11:59<37:58, 151.91s/it]
# [I 2025-06-30 14:01:22,646] Trial 34 finished with value: 0.8590210636471255 and parameters: {'n_estimators': 750, 'learning_rate': 0.010340932811900485, 'num_leaves': 70, 'max_depth': 12, 'min_child_samples': 47, 'subsample': 0.8664071915323829, 'colsample_bytree': 0.9782653472010754}. Best is trial 31 with value: 0.8597460176073124.
# Best trial: 31. Best value: 0.859746:  72%|███████▏  | 36/50 [1:14:01<33:21, 142.99s/it]
# [I 2025-06-30 14:03:24,812] Trial 35 finished with value: 0.8593549039727512 and parameters: {'n_estimators': 650, 'learning_rate': 0.013532764229515278, 'num_leaves': 64, 'max_depth': 15, 'min_child_samples': 56, 'subsample': 0.8380512172879712, 'colsample_bytree': 0.9349583554471492}. Best is trial 31 with value: 0.8597460176073124.
# Best trial: 31. Best value: 0.859746:  74%|███████▍  | 37/50 [1:16:35<31:42, 146.37s/it]
# [I 2025-06-30 14:05:59,077] Trial 36 finished with value: 0.8595567253659947 and parameters: {'n_estimators': 1000, 'learning_rate': 0.016046919101974512, 'num_leaves': 54, 'max_depth': 14, 'min_child_samples': 28, 'subsample': 0.8733819276392015, 'colsample_bytree': 0.9781743624292982}. Best is trial 31 with value: 0.8597460176073124.
# Best trial: 31. Best value: 0.859746:  76%|███████▌  | 38/50 [1:18:35<27:39, 138.31s/it]
# [I 2025-06-30 14:07:58,583] Trial 37 finished with value: 0.8580383345530007 and parameters: {'n_estimators': 1000, 'learning_rate': 0.03055557604492352, 'num_leaves': 33, 'max_depth': 14, 'min_child_samples': 23, 'subsample': 0.910981786281351, 'colsample_bytree': 0.9161156674256284}. Best is trial 31 with value: 0.8597460176073124.
# Best trial: 31. Best value: 0.859746:  78%|███████▊  | 39/50 [1:20:32<24:11, 131.99s/it]
# [I 2025-06-30 14:09:55,829] Trial 38 finished with value: 0.8569836403745594 and parameters: {'n_estimators': 900, 'learning_rate': 0.01691856153776875, 'num_leaves': 53, 'max_depth': 6, 'min_child_samples': 28, 'subsample': 0.8769675977547989, 'colsample_bytree': 0.951242770058717}. Best is trial 31 with value: 0.8597460176073124.
# Best trial: 31. Best value: 0.859746:  80%|████████  | 40/50 [1:23:05<23:03, 138.38s/it]
# [I 2025-06-30 14:12:29,129] Trial 39 finished with value: 0.8558076661505215 and parameters: {'n_estimators': 850, 'learning_rate': 0.0727056813364738, 'num_leaves': 76, 'max_depth': 8, 'min_child_samples': 41, 'subsample': 0.8982833602043305, 'colsample_bytree': 0.9392813394360552}. Best is trial 31 with value: 0.8597460176073124.
# Best trial: 31. Best value: 0.859746:  82%|████████▏ | 41/50 [1:25:39<21:27, 143.10s/it]
# [I 2025-06-30 14:15:03,243] Trial 40 finished with value: 0.8585360053960411 and parameters: {'n_estimators': 950, 'learning_rate': 0.02026943675597404, 'num_leaves': 60, 'max_depth': 15, 'min_child_samples': 13, 'subsample': 0.7740389296717372, 'colsample_bytree': 0.9810221958502928}. Best is trial 31 with value: 0.8597460176073124.
# Best trial: 31. Best value: 0.859746:  84%|████████▍ | 42/50 [1:27:48<18:31, 138.93s/it]
# [I 2025-06-30 14:17:12,427] Trial 41 finished with value: 0.8589005475945821 and parameters: {'n_estimators': 750, 'learning_rate': 0.014640421195129837, 'num_leaves': 50, 'max_depth': 13, 'min_child_samples': 69, 'subsample': 0.8254348514040495, 'colsample_bytree': 0.9773061148802722}. Best is trial 31 with value: 0.8597460176073124.
# Best trial: 31. Best value: 0.859746:  86%|████████▌ | 43/50 [1:29:22<14:37, 125.38s/it]
# [I 2025-06-30 14:18:46,193] Trial 42 finished with value: 0.8581592930892239 and parameters: {'n_estimators': 550, 'learning_rate': 0.012840004288831145, 'num_leaves': 57, 'max_depth': 14, 'min_child_samples': 57, 'subsample': 0.8555662213370676, 'colsample_bytree': 0.907807551466086}. Best is trial 31 with value: 0.8597460176073124.
# Best trial: 31. Best value: 0.859746:  88%|████████▊ | 44/50 [1:30:32<10:52, 108.78s/it]
# [I 2025-06-30 14:19:56,254] Trial 43 finished with value: 0.8569968979514864 and parameters: {'n_estimators': 450, 'learning_rate': 0.10235132277261721, 'num_leaves': 64, 'max_depth': 13, 'min_child_samples': 51, 'subsample': 0.8070919086826067, 'colsample_bytree': 0.9865259876266624}. Best is trial 31 with value: 0.8597460176073124.
# Best trial: 31. Best value: 0.859746:  90%|█████████ | 45/50 [1:32:57<09:57, 119.58s/it]
# [I 2025-06-30 14:22:21,021] Trial 44 finished with value: 0.8592994586475712 and parameters: {'n_estimators': 650, 'learning_rate': 0.016251520702286137, 'num_leaves': 69, 'max_depth': 15, 'min_child_samples': 74, 'subsample': 0.9055763080670347, 'colsample_bytree': 0.9507720496713925}. Best is trial 31 with value: 0.8597460176073124.
# Best trial: 31. Best value: 0.859746:  92%|█████████▏| 46/50 [1:35:29<08:36, 129.21s/it]
# [I 2025-06-30 14:24:52,698] Trial 45 finished with value: 0.859344650936227 and parameters: {'n_estimators': 800, 'learning_rate': 0.012478823859468014, 'num_leaves': 55, 'max_depth': 10, 'min_child_samples': 77, 'subsample': 0.8828566665265484, 'colsample_bytree': 0.9657790572713828}. Best is trial 31 with value: 0.8597460176073124.
# Best trial: 31. Best value: 0.859746:  94%|█████████▍| 47/50 [1:37:49<06:37, 132.42s/it]
# [I 2025-06-30 14:27:12,619] Trial 46 finished with value: 0.8590091488900603 and parameters: {'n_estimators': 850, 'learning_rate': 0.0187543388636072, 'num_leaves': 44, 'max_depth': 13, 'min_child_samples': 94, 'subsample': 0.8514767662617206, 'colsample_bytree': 0.9309816964174963}. Best is trial 31 with value: 0.8597460176073124.
# Best trial: 31. Best value: 0.859746:  96%|█████████▌| 48/50 [1:40:48<04:53, 146.63s/it]
# [I 2025-06-30 14:30:12,387] Trial 47 finished with value: 0.8593050348198288 and parameters: {'n_estimators': 950, 'learning_rate': 0.02784934346917005, 'num_leaves': 49, 'max_depth': 15, 'min_child_samples': 34, 'subsample': 0.8283219842164576, 'colsample_bytree': 0.9993497837857754}. Best is trial 31 with value: 0.8597460176073124.
# Best trial: 31. Best value: 0.859746:  98%|█████████▊| 49/50 [1:43:07<02:24, 144.35s/it]
# [I 2025-06-30 14:32:31,427] Trial 48 finished with value: 0.8586037949048064 and parameters: {'n_estimators': 700, 'learning_rate': 0.010318316130723535, 'num_leaves': 61, 'max_depth': 14, 'min_child_samples': 66, 'subsample': 0.9999817332966058, 'colsample_bytree': 0.8930671818821984}. Best is trial 31 with value: 0.8597460176073124.
# Best trial: 31. Best value: 0.859746: 100%|██████████| 50/50 [1:46:00<00:00, 127.21s/it]
# [I 2025-06-30 14:35:24,247] Trial 49 finished with value: 0.8590514611920661 and parameters: {'n_estimators': 750, 'learning_rate': 0.021153127973124575, 'num_leaves': 75, 'max_depth': 12, 'min_child_samples': 72, 'subsample': 0.8682962936559314, 'colsample_bytree': 0.9459680524307403}. Best is trial 31 with value: 0.8597460176073124.
#
# Optimierung abgeschlossen!
# Bester cross-validierter F1-Score: 0.8597
# Beste gefundene Hyperparameter für LGBM:
# {'n_estimators': 750, 'learning_rate': 0.013275070059726883, 'num_leaves': 68, 'max_depth': 15, 'min_child_samples': 70, 'subsample': 0.8787322489550233, 'colsample_bytree': 0.9901903617907937}
#
# --> Erstelle finale Pipeline mit den besten Hyperparametern...
# Trainiere das finale LGBM-Modell auf den Trainingsdaten...
# Finales Modell ist trainiert und bereit für die Evaluation.
#
# --------------------------------------------------------------------------------
#  EVALUATION AUF VALIDATION-DATEN
# --------------------------------------------------------------------------------
# X does not have valid feature names, but LGBMClassifier was fitted with feature namesX does not have valid feature names, but LGBMClassifier was fitted with feature names
# Klassifikations-Metriken:
#                precision    recall  f1-score   support
#
#        Normal       0.93      0.98      0.95     16738
# Mild_Moderate       0.55      0.39      0.46      1736
#        Severe       0.46      0.17      0.25       439
#       Extreme       0.36      0.04      0.08        95
#
#      accuracy                           0.90     19008
#     macro avg       0.58      0.40      0.43     19008
#  weighted avg       0.88      0.90      0.89     19008
# --------------------------------------------------------------------------------
#  EVALUATION AUF TEST-DATEN
# --------------------------------------------------------------------------------
# X does not have valid feature names, but LGBMClassifier was fitted with feature namesX does not have valid feature names, but LGBMClassifier was fitted with feature names
# Klassifikations-Metriken:
#                precision    recall  f1-score   support
#
#        Normal       0.84      0.93      0.88     13792
# Mild_Moderate       0.55      0.52      0.54      4848
#        Severe       0.55      0.39      0.46      2501
#       Extreme       0.68      0.39      0.49      1035
#
#      accuracy                           0.75     22176
#     macro avg       0.66      0.56      0.59     22176
#  weighted avg       0.74      0.75      0.74     22176
# ================================================================================
#  TEIL 3C: MODELLINTERPRETATION
# ================================================================================
#
# --> LightGBM Feature Importance (nach 'gain'):
#                           feature  importance
# 2                       sgi_trend       18855
# 39            sgi_seasonal_lag_6M       13098
# 34               sgi_trend_lag_3M       11445
# 36               sgi_resid_lag_6M        8832
# 9          ground_elevation_m_asl        7394
# 31                      sgi_resid        7317
# 27               sgi_resid_lag_1M        6460
# 40          precipitation_monthly        6339
# 4                sgi_trend_lag_6M        6001
# 15               sgi_resid_lag_3M        5997
# 28               sgi_label_lag_6M        5956
# 37                   ndvi_monthly        5955
# 38  withdrawal_industrial_monthly        5911
# 41              sgi_resid_lag_12M        5742
# 7     withdrawal_domestic_monthly        5723
# 24              sgi_trend_lag_12M        5719
# 29        air_temperature_monthly        5617
# 20            sgi_seasonal_lag_3M        5585
# 22                   sgi_seasonal        5387
# 5                sgi_label_lag_3M        5322
#
# --> Bereite Daten für SHAP-Analyse vor (Transformation durch Pipeline)...
#
# --> Berechne SHAP-Werte...
# DEBUG: SHAP-Werte-Typ: <class 'numpy.ndarray'>
# DEBUG: SHAP-Werte-ist-Liste: False (Ist direkt ein Array o.ä.)
# DEBUG: Shape des SHAP-Values-Arrays: (19008, 45, 4)
#
# --> Erstelle SHAP Feature Importance Plot (global)...
# INFO: SHAP-Werte sind ein 3D NumPy-Array. Aggregiere für globalen Bar-Plot.
# --> Erstelle SHAP Beeswarm Plots (Detailansicht) für jede Klasse...
#     - Erstelle Beeswarm Plot für Klasse: 'Normal' (Index 0)
#     - Erstelle Beeswarm Plot für Klasse: 'Mild_Moderate' (Index 1)
#     - Erstelle Beeswarm Plot für Klasse: 'Severe' (Index 2)
#     - Erstelle Beeswarm Plot für Klasse: 'Extreme' (Index 3)
# [SUCCESS] Teil 3 abgeschlossen.
#
# ================================================================================
#  TEIL 4: SPEICHERN DER ERGEBNISSE
# ================================================================================
# --> Testdaten mit Vorhersagen und Wahrscheinlichkeiten gespeichert: test_data_final_classification.csv
#
# Skript vollständig abgeschlossen.

# %% [markdown]
# # Klassifikations Pipeline XGBoost

# %%
# --- TEIL 0: Bibliotheken importieren und Setup ---
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import gc
import io

# Spezialisierte Bibliotheken
import pastas as ps                                      # Für hydrologische Zeitreihenanalyse, speziell für SGI-Berechnung
import pyarrow.dataset as ds                             # Zum effizienten Laden von Parquet-Dateien
import xgboost as xgb                                    # Das XGBoost-Modell, ein Gradient Boosting Framework (ersetzt lightgbm)
import shap                                              # Für die Modell-Interpretation (SHapley Additive exPlanations)
from statsmodels.tsa.seasonal import STL                 # Für die saisonale Zerlegung von Zeitreihen
import optuna

# Wichtige Werkzeuge von Scikit-learn
from sklearn.model_selection import GridSearchCV         # Zur automatischen Suche der besten Hyperparameter
from sklearn.pipeline import Pipeline                    # Um mehrere Verarbeitungsschritte zu einem Modell zu verketten
from sklearn.preprocessing import StandardScaler         # Zur Skalierung numerischer Features
from sklearn.impute import SimpleImputer                 # Zum Füllen von fehlenden Werten
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay # Zur Evaluation des Modells
from sklearn.metrics import f1_score
from sklearn.utils.class_weight import compute_sample_weight # +++ NEU +++
from sklearn.model_selection import cross_val_score # Wichtig für CV


# Helfer-Bibliotheken
from tqdm import tqdm                                    # Für schöne Fortschrittsbalken bei langen Schleifen
from contextlib import redirect_stdout                   # Um störende Ausgaben von Bibliotheken zu unterdrücken
# +++ IMPORTE BLEIBEN GLEICH +++


# --- Konfiguration ---
# Loglevel von 'pastas' reduzieren, um die Konsole sauber zu halten
ps.set_log_level("ERROR")
print("Starte Skript: XGBoost-Klassifikations-Pipeline")

# --- Definition der Features ---
# Hier werden die Spaltennamen für verschiedene Feature-Typen zentral definiert.
STATIC_CATEGORICAL_FEATURES = ["main_landuse"]
STATIC_NUMERICAL_FEATURES = ["ground_elevation_m_asl", "topographic_slope_degrees"]
DYNAMIC_NUMERICAL_FEATURES_RAW = [
    "groundwater_level_m_asl", "precipitation_gpcc_mm_year-1",
    "potential_evapotranspiration_era5_mm_year-1", "air_temperature_°C", "snow_depth_m",
    "ndvi_ratio", "lai_low_vegetation_ratio", "lai_high_vegetation_ratio",
    "withdrawal_industrial_m3_year-1", "withdrawal_domestic_m3_year-1"
]

# --- TEIL 1 & 2: DATEN LADEN UND FEATURE ENGINEERING ---
print("\n" + "="*80); print(" TEIL 1 & 2: DATEN LADEN UND FEATURE ENGINEERING"); print("="*80)

# --- Schritt 1.1: Statische Attribute laden und filtern ---
print("1.1 Lade statische Attribute und filtere relevante Stationen...")
path_attributes = "C:/MLmitPython/ML-Python/Daten/grow_attributes.parquet"
path_timeseries = "C:/MLmitPython/ML-Python/Daten/grow_timeseries.parquet"
try:
    attr_df_full = pd.read_parquet(path_attributes)
except FileNotFoundError: raise

# Filtere die Attribute nach den gewünschten Kriterien (Tschechien, lange Zeitreihen, keine Lücken etc.)
attr_filtered_df = attr_df_full[(attr_df_full["country"] == "CZE") & (attr_df_full["length_years"] >= 30) & (attr_df_full["gap_fraction"] == 0.0) & (pd.to_datetime(attr_df_full["ending_date"]) >= pd.Timestamp("2023-12-01"))]
if attr_filtered_df.empty: raise ValueError("Keine passende Zeitreihe für CZ für ML gefunden.")
cz_ids_for_ml = attr_filtered_df["GROW_ID"].dropna().unique().tolist()
print(f"--> {len(cz_ids_for_ml)} relevante Stationen für die Analyse gefunden.")

# --- Schritt 1.2: Dynamische Zeitreihen laden ---
print("\n1.2 Lade dynamische Zeitreihen für die ausgewählten Stationen...")
dynamic_feature_columns_to_load = ["GROW_ID", "date"] + DYNAMIC_NUMERICAL_FEATURES_RAW
try:
    # PyArrow wird für schnelles, speichereffizientes Laden der großen Parquet-Datei verwendet
    timeseries_dataset_raw = ds.dataset(path_timeseries, format="parquet")
    available_columns_in_parquet = timeseries_dataset_raw.schema.names
    columns_to_actually_load = [col for col in dynamic_feature_columns_to_load if col in available_columns_in_parquet]
    timeseries_table_raw = timeseries_dataset_raw.to_table(filter=ds.field("GROW_ID").isin(cz_ids_for_ml), columns=columns_to_actually_load)
    raw_ts_df_full = timeseries_table_raw.to_pandas()
except FileNotFoundError: raise
raw_ts_df_full["date"] = pd.to_datetime(raw_ts_df_full["date"])
print("--> Zeitreihen erfolgreich geladen.")

# --- Schritt 1.3: Erste Feature-Anpassungen ---
print("\n1.3 Berechne monatliche Features aus jährlichen Werten...")
if "precipitation_gpcc_mm_year-1" in raw_ts_df_full.columns: raw_ts_df_full["precipitation_gpcc_mm_month-1"] = (raw_ts_df_full["precipitation_gpcc_mm_year-1"] / 12)
if "potential_evapotranspiration_era5_mm_year-1" in raw_ts_df_full.columns: raw_ts_df_full["potential_evapotranspiration_era5_mm_month-1"] = (raw_ts_df_full["potential_evapotranspiration_era5_mm_year-1"] / 12)

# Gruppiere die Zeitreihen nach ihrer ID für die Einzelverarbeitung
grouped_ts_data = raw_ts_df_full.set_index('date').groupby('GROW_ID'); del raw_ts_df_full; gc.collect()


# --- Schritt 1.4: Haupt-Feature-Engineering pro Station ---
print("\n1.4 Führe SGI-Berechnung und Feature-Engineering pro Station durch...")
# Definiere eine Funktion, die alle Schritte für eine einzelne Station durchführt
def process_grow_id_data(grow_id_data):
    # Resample Grundwasserstand auf monatliche Werte
    gwl_series_monthly = grow_id_data["groundwater_level_m_asl"].dropna().resample('MS').mean()
    if gwl_series_monthly.empty or len(gwl_series_monthly.dropna()) < 120: return None
    
    # Berechne den Standardized Groundwater Index (SGI) mit der 'pastas'-Bibliothek
    try:
        with redirect_stdout(io.StringIO()): # Unterdrückt Konsolenausgaben von pastas
            sgi_observed_monthly = ps.stats.sgi(gwl_series_monthly)
        if sgi_observed_monthly.empty or sgi_observed_monthly.isnull().all(): return None
    except Exception: return None
    
    # Zerlege die SGI-Zeitreihe in Trend, Saison und Residuum (Rest)
    sgi_trend, sgi_seasonal, sgi_resid = (pd.Series(dtype=np.float32), pd.Series(dtype=np.float32), pd.Series(dtype=np.float32))
    sgi_for_stl = sgi_observed_monthly.dropna()
    if len(sgi_for_stl) >= 25: # STL benötigt eine minimale Anzahl an Datenpunkten
        try:
            stl = STL(sgi_for_stl, period=12, robust=True); res_stl = stl.fit()
            sgi_trend, sgi_seasonal, sgi_resid = (res_stl.trend, res_stl.seasonal, res_stl.resid)
        except Exception: pass
        
    # Sammle alle berechneten und originalen Features in einem Dictionary
    monthly_features_dict = {'sgi_label': sgi_observed_monthly, 'sgi_trend': sgi_trend, 'sgi_seasonal': sgi_seasonal, 'sgi_resid': sgi_resid}
    dynamic_map = {"precipitation_gpcc_mm_month-1": "precipitation_monthly", "potential_evapotranspiration_era5_mm_month-1": "evapotranspiration_monthly", "air_temperature_°C": "air_temperature_monthly", "snow_depth_m": "snow_depth_monthly", "ndvi_ratio": "ndvi_monthly", "lai_low_vegetation_ratio": "lai_low_veg_monthly", "lai_high_vegetation_ratio": "lai_high_veg_monthly"}
    for orig, target in dynamic_map.items(): monthly_features_dict[target] = grow_id_data[orig].dropna().resample('MS').mean().reindex(sgi_observed_monthly.index) if orig in grow_id_data.columns else pd.Series(index=sgi_observed_monthly.index, dtype=np.float32)
    yearly_map = {"withdrawal_industrial_m3_year-1": "withdrawal_industrial_monthly", "withdrawal_domestic_m3_year-1": "withdrawal_domestic_monthly"}
    for orig, target in yearly_map.items():
        if orig in grow_id_data.columns:
            series_yearly = grow_id_data[orig].dropna(); series_yearly = series_yearly[~series_yearly.index.duplicated(keep='first')] if not series_yearly.index.is_unique else series_yearly; monthly_features_dict[target] = series_yearly.resample('MS').ffill().reindex(sgi_observed_monthly.index)
        else: monthly_features_dict[target] = pd.Series(index=sgi_observed_monthly.index, dtype=np.float32)
        
    return pd.DataFrame(monthly_features_dict).dropna(subset=['sgi_label'])

# Wende die Funktion auf alle Stations-Gruppen an und zeige einen Fortschrittsbalken
processed_groups = []
for grow_id, group_data in tqdm(grouped_ts_data, desc="SGI-Berechnung & Dekomposition"):
    processed_df = process_grow_id_data(group_data)
    if processed_df is not None and not processed_df.empty: processed_df['GROW_ID'] = grow_id; processed_groups.append(processed_df)
if not processed_groups: raise ValueError("Keine Daten für ML-Modell nach Verarbeitung.")

# --- Schritt 1.5: Finale Datenzusammenführung und Feature-Erstellung ---
print("\n1.5 Führe dynamische und statische Features zusammen...")
df_ml_input_dynamic = pd.concat(processed_groups); del processed_groups; gc.collect()
static_features_to_select = ["GROW_ID"] + STATIC_NUMERICAL_FEATURES + STATIC_CATEGORICAL_FEATURES
static_features_to_select = [col for col in static_features_to_select if col in attr_df_full.columns]
attr_df_ml_static = attr_df_full[attr_df_full['GROW_ID'].isin(cz_ids_for_ml)][static_features_to_select].copy().drop_duplicates(subset=['GROW_ID'], keep='first')
df_ml_input_dynamic.reset_index(inplace=True)
df_ml_input = pd.merge(df_ml_input_dynamic, attr_df_ml_static, on="GROW_ID", how="left").set_index('date')
del df_ml_input_dynamic, attr_df_ml_static, attr_df_full; gc.collect()
df_ml_processed = df_ml_input.copy(); del df_ml_input; gc.collect()

print("\n1.6 Erstelle zeitversetzte (Lag) Features und Zielvariable...")
# Erstelle Lag-Features für die SGI-Komponenten (Werte von vor 1, 3, 6, 12 Monaten)
for lag_col_base in ['sgi_label', 'sgi_trend', 'sgi_seasonal', 'sgi_resid']:
    if lag_col_base in df_ml_processed.columns:
        for lag_val in [1, 3, 6, 12]: df_ml_processed[f'{lag_col_base}_lag_{lag_val}M'] = df_ml_processed.groupby('GROW_ID')[lag_col_base].shift(lag_val)

df_ml_processed['month_num'] = df_ml_processed.index.month.astype(np.int8)
df_ml_processed['year'] = df_ml_processed.index.year.astype(np.int32)

# Erstelle die Zielvariable: der SGI-Wert 6 Monate in der Zukunft
VORHERSAGE_HORIZONT_MONATE = 6
sgi_target_col_continuous = f'sgi_target_{VORHERSAGE_HORIZONT_MONATE}M_future'
df_ml_processed[sgi_target_col_continuous] = df_ml_processed.groupby('GROW_ID')['sgi_label'].shift(-VORHERSAGE_HORIZONT_MONATE)

# --- Schritt 1.7: Zielvariable in Klassen umwandeln und Features vorbereiten ---
print("\n1.7 Wandle Zielvariable in Klassen um und kodiere kategorische Features...")
def sgi_to_drought_class(z_score):
    if pd.isna(z_score): return None
    if z_score > -0.84: return 'Normal'
    if -1.50 <= z_score <= -0.84: return 'Mild_Moderate'
    if -2.00 <= z_score <= -1.51: return 'Severe'
    return 'Extreme'
df_ml_processed['drought_class_str'] = df_ml_processed[sgi_target_col_continuous].apply(sgi_to_drought_class)
class_mapping = {'Normal': 0, 'Mild_Moderate': 1, 'Severe': 2, 'Extreme': 3}
df_ml_processed['drought_class_target'] = df_ml_processed['drought_class_str'].map(class_mapping).astype('Int64')
label_column_ml = 'drought_class_target'

# Definiere die zu kodierenden Spalten dynamisch, basierend auf dem, was wirklich im DataFrame ist
print("\n1.7.1 Kodierung der kategorischen Features...")
categorical_cols_to_encode = [col for col in STATIC_CATEGORICAL_FEATURES if col in df_ml_processed.columns]
if 'month_num' in df_ml_processed.columns:
    categorical_cols_to_encode.append('month_num')

print(f"--> Folgende kategorische Spalten werden kodiert: {categorical_cols_to_encode}")

# Die Schleife bleibt gleich, verarbeitet aber nur existierende Spalten
dummy_encoded_cols_list = []
for col_to_encode in categorical_cols_to_encode:
    print(f"     - Kodiere '{col_to_encode}'...")
    dummies = pd.get_dummies(df_ml_processed[col_to_encode], prefix=col_to_encode, dummy_na=False, dtype=np.int8)
    df_ml_processed = pd.concat([df_ml_processed, dummies], axis=1)
    df_ml_processed.drop(columns=[col_to_encode], inplace=True)
    dummy_encoded_cols_list.extend(dummies.columns.tolist())

# --- Schritt 1.8: Finale Datenbereinigung ---
print("\n1.8 Bereinige finale Datensätze...")
# Fülle verbleibende Lücken in numerischen Spalten mit dem Median
numerical_static_cols_for_imputation = [col for col in STATIC_NUMERICAL_FEATURES if col in df_ml_processed.columns]
if numerical_static_cols_for_imputation:
    df_ml_processed[numerical_static_cols_for_imputation] = SimpleImputer(strategy='median').fit_transform(df_ml_processed[numerical_static_cols_for_imputation])

# Definiere die finale Liste aller Features für das Modell
base_features_ml = ["precipitation_monthly", "evapotranspiration_monthly", "air_temperature_monthly", "snow_depth_monthly", "ndvi_monthly", "lai_low_veg_monthly", "lai_high_veg_monthly", "withdrawal_industrial_monthly", "withdrawal_domestic_monthly"]
lag_features_ml = [col for col in df_ml_processed.columns if '_lag_' in col]
current_sgi_features = ['sgi_label', 'sgi_trend', 'sgi_seasonal', 'sgi_resid']
features_columns_ml = list(set([col for col in base_features_ml if col in df_ml_processed.columns] + lag_features_ml + current_sgi_features + numerical_static_cols_for_imputation + dummy_encoded_cols_list))
# +++ DIESE ZEILE BITTE EINFÜGEN +++
columns_to_check_for_dropna_smart = ['sgi_label_lag_1M', 'precipitation_monthly']
# Entferne Zeilen, in denen wichtige Features oder das Label fehlen
df_ml_processed.dropna(subset=[label_column_ml] + [col for col in columns_to_check_for_dropna_smart if col in df_ml_processed.columns], inplace=True)
df_ml_processed[label_column_ml] = df_ml_processed[label_column_ml].astype(int)

# Finale Aufteilung in X (Features) und y (Zielvariable)
X_all_features_raw = df_ml_processed[features_columns_ml].copy()
y_all_labels = df_ml_processed[label_column_ml].copy()
X_meta_for_split = df_ml_processed[['GROW_ID', 'year']].copy()
del df_ml_processed; gc.collect()
print("\n[SUCCESS] Teil 1 & 2 abgeschlossen.")


# --- TEIL 3: MODELLTRAINING & EVALUATION ---
print("\n" + "="*80); print(" TEIL 3: MODELLTRAINING & EVALUATION"); print("="*80)

# --- Schritt 3.1: Zeitbasierter Train-Validation-Test Split ---
temp_year_series = X_meta_for_split['year']
unique_years_ml = np.sort(temp_year_series.unique())
split_year_1 = int(np.percentile(unique_years_ml, 80))
split_year_2 = int(np.percentile(unique_years_ml, 90))
print(f"--> Erstelle zeitbasierten 80/10/10 Split:")
print(f"       - Trainingsdaten: Jahre < {split_year_1} (80%)")
print(f"       - Validierungsdaten: Jahre >= {split_year_1} und < {split_year_2} (10%)")
print(f"       - Testdaten: Jahre >= {split_year_2} (10%)")
train_mask = temp_year_series < split_year_1
val_mask = (temp_year_series >= split_year_1) & (temp_year_series < split_year_2)
test_mask = temp_year_series >= split_year_2
X_train_raw, X_val_raw, X_test_raw = X_all_features_raw[train_mask], X_all_features_raw[val_mask], X_all_features_raw[test_mask]
y_train, y_val, y_test = y_all_labels[train_mask], y_all_labels[val_mask], y_all_labels[test_mask]
print(f"\nGröße der Datensätze:")
print(f"       - Training:   {X_train_raw.shape[0]} Zeilen")
print(f"       - Validation: {X_val_raw.shape[0]} Zeilen")
print(f"       - Test:       {X_test_raw.shape[0]} Zeilen")
del X_all_features_raw, y_all_labels, X_meta_for_split; gc.collect()

# --- Schritt 3.2: Finale Feature-Übersicht ---
print("\n" + "-"*80)
features_in_model = sorted(X_train_raw.columns.tolist())
print(f"--> Folgende {len(features_in_model)} Features werden für das Modell verwendet:")
print("-" * 80)
max_len = max(len(f) for f in features_in_model) + 2
num_columns = 4
for i in range(0, len(features_in_model), num_columns):
    row = [f"{feat:<{max_len}}" for feat in features_in_model[i:i+num_columns]]
    print("".join(row))
print("-" * 80)


# --- Schritt 3.3: OPTIMALES HYPERPARAMETER-TUNING MIT KREUZVALIDIERUNG IN OPTUNA ---
print("\n--> Starte optimales Modell-Tuning (XGBoost) mit Optuna und 5-facher Kreuzvalidierung...")

# Berechne die Sample-Gewichte. Diese benötigen wir weiterhin.
print("Berechne Sample-Gewichte für den Ausgleich von Klassen-Ungleichgewicht...")
sample_weights = compute_sample_weight(class_weight='balanced', y=y_train)


# Definiere die "Objective"-Funktion mit Kreuzvalidierung
def objective(trial):
    # Die Parameter-Definition bleibt exakt gleich wie zuvor
    param = {
        'verbosity': 0, 'objective': 'multi:softmax', 'eval_metric': 'mlogloss',
        'num_class': len(class_mapping), 'use_label_encoder': False, 'random_state': 42,
        'n_estimators': trial.suggest_int('n_estimators', 200, 1000, step=50),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2, log=True),
        'max_depth': trial.suggest_int('max_depth', 5, 15),
        'subsample': trial.suggest_float('subsample', 0.6, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'gamma': trial.suggest_float('gamma', 1e-8, 1.0, log=True),
        'reg_alpha': trial.suggest_float('reg_alpha', 1e-8, 1.0, log=True),
        'reg_lambda': trial.suggest_float('reg_lambda', 1e-8, 1.0, log=True),
    }

    # +++ NEU: Erstelle eine vollständige Pipeline INNTERHALB des Trials +++
    # Das stellt sicher, dass Imputer/Scaler auf jeden Fold der CV korrekt angewendet werden.
    pipeline_cv = Pipeline(steps=[
        ('imputer', SimpleImputer(strategy='mean')),
        ('scaler', StandardScaler()),
        ('classifier', xgb.XGBClassifier(**param))
    ])

    # Wir nutzen X_train_raw, damit die Pipeline die Rohdaten für jeden Fold selbst verarbeiten kann.
    scores = cross_val_score(
        pipeline_cv,
        X=X_train_raw,
        y=y_train,
        scoring='f1_weighted',
        cv=5,  # Anzahl der Folds für die Kreuzvalidierung
        n_jobs=-1, # Parallelisiere die Folds, wenn möglich
        fit_params={'classifier__sample_weight': sample_weights} # Übergebe die Gewichte
    )
    
    # Optuna soll den DURCHSCHNITTLICHEN Score der Kreuzvalidierung maximieren
    return scores.mean()

# Der restliche Optuna-Loop bleibt gleich, aber sei auf eine längere Laufzeit vorbereitet!
study = optuna.create_study(direction='maximize')
print(f"\nStarte Optuna-Suche für XGBoost mit 50 Trials und 3-facher CV")
study.optimize(objective, n_trials=50, show_progress_bar=True)

# (Der Code zum Erstellen der finalen Pipeline bleibt exakt gleich wie im vorherigen Schritt)
print("\nOptimierung abgeschlossen!")
print(f"Bester cross-validierter F1-Score: {study.best_value:.4f}")
print("Beste gefundene Hyperparameter für XGBoost:")
print(study.best_params)

print("\n--> Erstelle finale Pipeline mit den besten Hyperparametern...")
best_params_xgb = study.best_params
best_model_pipeline = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler()),
    ('classifier', xgb.XGBClassifier(
        objective='multi:softmax', num_class=len(class_mapping), use_label_encoder=False,
        random_state=42, eval_metric='mlogloss', **best_params_xgb
    ))
])

print("Trainiere das finale XGBoost-Modell auf den Trainingsdaten mit Sample-Gewichtung...")
best_model_pipeline.fit(X_train_raw, y_train, classifier__sample_weight=sample_weights)
print("Finales Modell ist trainiert und bereit für die Evaluation.")


# --- Schritt 3.4: Evaluation des besten Modells ---
def evaluate_and_plot(X_data, y_data, dataset_name, model_pipeline):
    """Eine Helfer-Funktion zur standardisierten Evaluation und Visualisierung."""
    if X_data.empty or y_data.empty:
        print(f"\n{dataset_name}-Datensatz ist leer. Evaluation wird übersprungen.")
        return None, None
    print("\n" + "-"*80); print(f" EVALUATION AUF {dataset_name.upper()}-DATEN"); print("-" * 80)
    
    # Mache Vorhersagen
    y_pred = model_pipeline.predict(X_data)
    y_pred_proba = model_pipeline.predict_proba(X_data)
    
    # Gebe den Klassifikations-Report aus
    class_names = list(class_mapping.keys())
    print("\nKlassifikations-Metriken:")
    print(classification_report(y_data, y_pred, labels=range(len(class_names)), target_names=class_names, zero_division=0))
    
    # Plotte die Konfusionsmatrix
    cm = confusion_matrix(y_data, y_pred, labels=range(len(class_names)))
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
    fig, ax = plt.subplots(figsize=(10, 8)); disp.plot(cmap=plt.cm.Blues, ax=ax, xticks_rotation='vertical'); ax.set_title(f'Klassifikationsmatrix für {dataset_name}'); plt.tight_layout(); plt.show()
    
    return y_pred, y_pred_proba

# Führe die Evaluation für Validierungs- und Test-Set durch
y_val_pred, y_val_pred_proba = evaluate_and_plot(X_val_raw, y_val, "Validation", best_model_pipeline)
y_test_pred, y_test_pred_proba = evaluate_and_plot(X_test_raw, y_test, "Test", best_model_pipeline)


# --- Schritt 3.5: Umfassende Modellinterpretation ---
print("\n" + "="*80); print(" TEIL 3C: MODELLINTERPRETATION"); print("="*80)
try:
    if not X_val_raw.empty:
        # Extrahiere den trainierten Classifier aus der Pipeline
        xgb_classifier = best_model_pipeline.named_steps['classifier'] # Beachte: Jetzt ist es xgb_classifier
        
        # Klassische Feature Importance direkt vom Modell (basiert auf "gain" oder "split")
        print("\n--> XGBoost Feature Importance (nach 'gain'):") # Angepasst für XGBoost
        feature_importance_df = pd.DataFrame({
            'feature': X_train_raw.columns,
            'importance': xgb_classifier.feature_importances_
        }).sort_values('importance', ascending=False).head(20)
        print(feature_importance_df)

        # SHAP-Analyse für eine tiefere, robustere Interpretation
        print("\n--> Bereite Daten für SHAP-Analyse vor (Transformation durch Pipeline)...")
        # Die Daten müssen genauso transformiert werden, wie es das Modell beim Training gesehen hat.
        X_val_transformed = best_model_pipeline.named_steps['imputer'].transform(X_val_raw)
        X_val_transformed = best_model_pipeline.named_steps['scaler'].transform(X_val_transformed)
        X_val_transformed_df = pd.DataFrame(X_val_transformed, columns=X_val_raw.columns, index=X_val_raw.index)

        print("\n--> Berechne SHAP-Werte...")
        # TreeExplainer ist speziell für baumbasierte Modelle wie XGBoost optimiert.
        explainer = shap.TreeExplainer(xgb_classifier) # Nutze den xgb_classifier
        shap_values = explainer.shap_values(X_val_transformed_df)
        
        # --- DEBUGGING-AUSGABEN BEIBEHALTEN ---
        print(f"DEBUG: SHAP-Werte-Typ: {type(shap_values)}")
        if isinstance(shap_values, list):
            print(f"DEBUG: SHAP-Werte-ist-Liste: True, Anzahl der Elemente: {len(shap_values)}")
            if len(shap_values) > 0:
                print(f"DEBUG: Typ des ersten SHAP-Array-Elements: {type(shap_values[0])}")
                if hasattr(shap_values[0], 'shape'):
                    print(f"DEBUG: Shape des ersten SHAP-Array-Elements: {shap_values[0].shape}")
        else:
            print(f"DEBUG: SHAP-Werte-ist-Liste: False (Ist direkt ein Array o.ä.)")
            if hasattr(shap_values, 'shape'):
                print(f"DEBUG: Shape des SHAP-Values-Arrays: {shap_values.shape}")
        # --- ENDE DEBUGGING-AUSGABEN ---

        MAX_SHAP_FEATURES = 40
        
        # --- Globaler SHAP Feature Importance Plot (Bar-Diagramm) ---
        print("\n--> Erstelle SHAP Feature Importance Plot (global)...")
        
        # NEU: Unterscheidung, ob shap_values ein Array oder eine Liste ist (gleiche Logik wie bei LGBM)
        if isinstance(shap_values, np.ndarray) and shap_values.ndim == 3: # Dies ist der Fall, der jetzt eintritt!
            print("INFO: SHAP-Werte sind ein 3D NumPy-Array. Aggregiere für globalen Bar-Plot.")
            # Aggregiere die SHAP-Werte für den globalen Bar-Plot
            # Wir mitteln über die Klassen (Achse 2) und nehmen den absoluten Wert
            shap_values_for_global_plot = np.mean(np.abs(shap_values), axis=2) 
            
            # Jetzt plotten wir mit diesem 2D-Array
            shap.summary_plot(shap_values_for_global_plot, X_val_transformed_df, plot_type="bar", max_display=MAX_SHAP_FEATURES, show=False)
            plt.title("SHAP Feature Importance (Globaler Durchschnitt über alle Klassen) - XGBoost") # Titel angepasst
            plt.tight_layout()
            plt.show()
            
            # --- SHAP Beeswarm Plots (Detailansicht) für jede Klasse ---
            print("\n--> Erstelle SHAP Beeswarm Plots (Detailansicht) für jede Klasse...")
            # Jetzt iterieren wir über die Klassen-Achse (Achse 2) des 3D-Arrays
            for i, class_name in enumerate(list(class_mapping.keys())):
                print(f"    - Erstelle Beeswarm Plot für Klasse: '{class_name}' (Index {i}) - XGBoost") # Info angepasst
                plt.figure(figsize=(12, 8))
                shap.summary_plot(shap_values[:, :, i], X_val_transformed_df, max_display=MAX_SHAP_FEATURES, feature_names=X_val_transformed_df.columns, show=False)
                plt.title(f"SHAP-Werte für Klasse: '{class_name}' - XGBoost") # Titel angepasst
                plt.tight_layout()
                plt.show()
                
        elif isinstance(shap_values, list) and len(shap_values) > 1: # Fall für Liste von Arrays (alternative SHAP-Ausgabe)
            print("INFO: SHAP-Werte sind Liste für Multiklasse. Aggregiere für globalen Bar-Plot.")
            shap_values_for_global_plot = np.mean(np.abs(np.array(shap_values)), axis=0)
            
            shap.summary_plot(shap_values_for_global_plot, X_val_transformed_df, plot_type="bar", max_display=MAX_SHAP_FEATURES, show=False)
            plt.title("SHAP Feature Importance (Globaler Durchschnitt über alle Klassen) - XGBoost") # Titel angepasst
            plt.tight_layout()
            plt.show()
            
            # Beeswarm Plots pro Klasse aus der Liste
            print("\n--> Erstelle SHAP Beeswarm Plots (Detailansicht) für jede Klasse...")
            if len(shap_values) == len(class_mapping):
                for i, class_name in enumerate(list(class_mapping.keys())):
                    print(f"    - Erstelle Beeswarm Plot für Klasse: '{class_name}' (Index {i}) - XGBoost") # Info angepasst
                    plt.figure(figsize=(12, 8))
                    shap.summary_plot(shap_values[i], X_val_transformed_df, max_display=MAX_SHAP_FEATURES, feature_names=X_val_transformed_df.columns, show=False)
                    plt.title(f"SHAP-Werte für Klasse: '{class_name}' - XGBoost") # Titel angepasst
                    plt.tight_layout()
                    plt.show()
            else:
                print(f"WARNUNG: Anzahl der SHAP-Werte-Listen ({len(shap_values)}) stimmt nicht mit der Anzahl der Klassen ({len(class_mapping)}) überein. Überspringe Beeswarm Plots pro Klasse.")
                
        else: # Dies wird ausgeführt, wenn shap_values KEINE Liste ist ODER eine Liste mit nur einem Element (was auf ein binäres Problem hindeutet)
            print("INFO: SHAP-Werte sind kein Multiklassen-Format (oder nur eine Klasse). Erstelle einen einzelnen globalen Beeswarm/Bar-Plot.")
            shap.summary_plot(shap_values, X_val_transformed_df, max_display=MAX_SHAP_FEATURES, feature_names=X_val_transformed_df.columns, show=False)
            plt.title("SHAP-Werte (Gesamt / Binäre Klassifikation) - XGBoost") # Titel angepasst
            plt.tight_layout()
            plt.show()
            print("WARNUNG: Keine Beeswarm Plots pro Klasse möglich, da SHAP-Werte nicht im Multiklassen-Listenformat vorliegen.")
            
    else:
        print("Validierungsdaten sind leer, SHAP-Analyse wird übersprungen.")
except Exception as e:
    print(f"Fehler bei der SHAP-Analyse: {e}")
    import traceback
    traceback.print_exc()

print("\n[SUCCESS] Teil 3 abgeschlossen.")

# --- TEIL 4: SPEICHERN DER ERGEBNISSE ---
print("\n" + "="*80); print(" TEIL 4: SPEICHERN DER ERGEBNISSE"); print("=" * 80)
if not X_test_raw.empty:
    test_results_df = X_test_raw.copy()
    test_results_df[label_column_ml] = y_test
    test_results_df['prediction'] = y_test_pred
    proba_df = pd.DataFrame(y_test_pred_proba, columns=[f'prediction_proba_{cls}' for cls in class_mapping.keys()], index=test_results_df.index)
    test_results_df = pd.concat([test_results_df, proba_df], axis=1)
    
    # Speichere das DataFrame als CSV-Datei
    # Dateiname geändert, um Konflikte zu vermeiden, wenn du beide Modelle im selben Ordner testest
    test_results_df.to_csv("test_data_final_classification_xgboost.csv", index=True) 
    print(f"--> Testdaten mit Vorhersagen und Wahrscheinlichkeiten gespeichert: test_data_final_classification_xgboost.csv")
else:
    print("--> Testdaten sind leer, keine Speicherung.")

print("\nSkript vollständig abgeschlossen.")

# %% [markdown]
# # Klassifkations Pipeline Feed Forward Netz

# %%
# --- TEIL 0: Bibliotheken importieren und Setup ---
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pastas as ps
import pyarrow.dataset as ds
import tensorflow as tf # Spezifisch für Neuronale Netze (Keras/TensorFlow)
from sklearn.utils import class_weight # Für die Handhabung ungleicher Klassenverteilungen
import shap # Für die Modell-Interpretation (SHapley Additive exPlanations)
from sklearn.preprocessing import StandardScaler # Zur Skalierung numerischer Features
from sklearn.impute import SimpleImputer # Zum Füllen von fehlenden Werten
import gc # Für die manuelle Speicherbereinigung
from statsmodels.tsa.seasonal import STL # Für die saisonale Zerlegung von Zeitreihen
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay # Zur Evaluation des Modells
from tqdm import tqdm # Für schöne Fortschrittsbalken bei langen Schleifen
from contextlib import redirect_stdout # Um störende Ausgaben von Bibliotheken zu unterdrücken
import io # Für die Umleitung von Ausgaben

# --- Konfiguration ---
# Loglevel von 'pastas' reduzieren, um die Konsole sauber zu halten
ps.set_log_level("ERROR")
print("Starte Skript: Klassifikations-Pipeline mit NEURONALEM NETZ")

# Setzen von Random Seeds für Reproduzierbarkeit
np.random.seed(42)
tf.random.set_seed(42)


# --- Definition der Features (UNVERÄNDERT) ---
# Hier werden die Spaltennamen für verschiedene Feature-Typen zentral definiert.
STATIC_CATEGORICAL_FEATURES = ["main_landuse"]
STATIC_NUMERICAL_FEATURES = ["ground_elevation_m_asl", "topographic_slope_degrees"]
DYNAMIC_NUMERICAL_FEATURES_RAW = [
    "groundwater_level_m_asl", "precipitation_gpcc_mm_year-1",
    "potential_evapotranspiration_era5_mm_year-1", "air_temperature_°C", "snow_depth_m",
    "ndvi_ratio", "lai_low_vegetation_ratio", "lai_high_vegetation_ratio",
    "withdrawal_industrial_m3_year-1", "withdrawal_domestic_m3_year-1"
]

# --- TEIL 1 & 2: DATEN LADEN UND FEATURE ENGINEERING ---
print("\n" + "="*80); print(" TEIL 1 & 2: DATEN LADEN UND FEATURE ENGINEERING"); print("="*80)

# --- Schritt 1.1: Statische Attribute laden und filtern ---
print("1.1 Lade statische Attribute und filtere relevante Stationen...")
path_attributes = "C:/MLmitPython/ML-Python/Daten/grow_attributes.parquet"
path_timeseries = "C:/MLmitPython/ML-Python/Daten/grow_timeseries.parquet"
try:
    attr_df_full = pd.read_parquet(path_attributes)
except FileNotFoundError: raise

# Filtere die Attribute nach den gewünschten Kriterien (Tschechien, lange Zeitreihen, keine Lücken etc.)
attr_filtered_df = attr_df_full[(attr_df_full["country"] == "CZE") & (attr_df_full["length_years"] >= 30) & (attr_df_full["gap_fraction"] == 0.0) & (pd.to_datetime(attr_df_full["ending_date"]) >= pd.Timestamp("2023-12-01"))]
if attr_filtered_df.empty: raise ValueError("Keine passende Zeitreihe für CZ für ML gefunden.")
cz_ids_for_ml = attr_filtered_df["GROW_ID"].dropna().unique().tolist()
print(f"--> {len(cz_ids_for_ml)} relevante Stationen für die Analyse gefunden.")

# --- Schritt 1.2: Dynamische Zeitreihen laden ---
print("\n1.2 Lade dynamische Zeitreihen für die ausgewählten Stationen...")
dynamic_feature_columns_to_load = ["GROW_ID", "date"] + DYNAMIC_NUMERICAL_FEATURES_RAW
try:
    # PyArrow wird für schnelles, speichereffizientes Laden der großen Parquet-Datei verwendet
    timeseries_dataset_raw = ds.dataset(path_timeseries, format="parquet")
    available_columns_in_parquet = timeseries_dataset_raw.schema.names
    columns_to_actually_load = [col for col in dynamic_feature_columns_to_load if col in available_columns_in_parquet]
    timeseries_table_raw = timeseries_dataset_raw.to_table(filter=ds.field("GROW_ID").isin(cz_ids_for_ml), columns=columns_to_actually_load)
    raw_ts_df_full = timeseries_table_raw.to_pandas(self_destruct=True, split_blocks=True, zero_copy_only=False)
except FileNotFoundError: raise
raw_ts_df_full["date"] = pd.to_datetime(raw_ts_df_full["date"])
print("--> Zeitreihen erfolgreich geladen.")

# --- Schritt 1.3: Erste Feature-Anpassungen ---
print("\n1.3 Berechne monatliche Features aus jährlichen Werten...")
if "precipitation_gpcc_mm_year-1" in raw_ts_df_full.columns: raw_ts_df_full["precipitation_gpcc_mm_month-1"] = (raw_ts_df_full["precipitation_gpcc_mm_year-1"] / 12)
if "potential_evapotranspiration_era5_mm_year-1" in raw_ts_df_full.columns: raw_ts_df_full["potential_evapotranspiration_era5_mm_month-1"] = (raw_ts_df_full["potential_evapotranspiration_era5_mm_year-1"] / 12)

# Gruppiere die Zeitreihen nach ihrer ID für die Einzelverarbeitung
grouped_ts_data = raw_ts_df_full.set_index('date').groupby('GROW_ID'); del raw_ts_df_full; gc.collect()

# --- Schritt 1.4: Haupt-Feature-Engineering pro Station ---
print("\n1.4 Führe SGI-Berechnung und Feature-Engineering pro Station durch...")
# Definiere eine Funktion, die alle Schritte für eine einzelne Station durchführt
def process_grow_id_data(grow_id_data):
    # Resample Grundwasserstand auf monatliche Werte
    gwl_series_raw = grow_id_data["groundwater_level_m_asl"].dropna()
    if gwl_series_raw.empty or len(gwl_series_raw.resample('MS').mean().dropna()) < 120: return None # Mindestens 10 Jahre Daten benötigt
    gwl_series_monthly = gwl_series_raw.resample('MS').mean()
    
    # Berechne den Standardized Groundwater Index (SGI) mit der 'pastas'-Bibliothek
    try:
        with redirect_stdout(io.StringIO()): # Unterdrückt Konsolenausgaben von pastas
            sgi_observed_monthly = ps.stats.sgi(gwl_series_monthly)
        if sgi_observed_monthly.empty or sgi_observed_monthly.isnull().all(): return None
    except Exception: return None
    
    # Zerlege die SGI-Zeitreihe in Trend, Saison und Residuum (Rest)
    sgi_trend, sgi_seasonal, sgi_resid = (pd.Series(dtype=np.float32), pd.Series(dtype=np.float32), pd.Series(dtype=np.float32))
    sgi_for_stl = sgi_observed_monthly.dropna()
    if len(sgi_for_stl) >= 25: # STL benötigt eine minimale Anzahl an Datenpunkten
        try:
            stl = STL(sgi_for_stl, period=12, robust=True); res_stl = stl.fit()
            sgi_trend, sgi_seasonal, sgi_resid = (res_stl.trend.reindex(sgi_observed_monthly.index), res_stl.seasonal.reindex(sgi_observed_monthly.index), res_stl.resid.reindex(sgi_observed_monthly.index))
        except Exception: pass
        
    # Sammle alle berechneten und originalen Features in einem Dictionary
    monthly_features_dict = {'sgi_label': sgi_observed_monthly, 'sgi_trend': sgi_trend, 'sgi_seasonal': sgi_seasonal, 'sgi_resid': sgi_resid}
    dynamic_map = {"precipitation_gpcc_mm_month-1": "precipitation_monthly", "potential_evapotranspiration_era5_mm_month-1": "evapotranspiration_monthly", "air_temperature_°C": "air_temperature_monthly", "snow_depth_m": "snow_depth_monthly", "ndvi_ratio": "ndvi_monthly", "lai_low_vegetation_ratio": "lai_low_veg_monthly", "lai_high_vegetation_ratio": "lai_high_veg_monthly"}
    for orig, target in dynamic_map.items(): monthly_features_dict[target] = grow_id_data[orig].dropna().resample('MS').mean().reindex(sgi_observed_monthly.index) if orig in grow_id_data.columns else pd.Series(index=sgi_observed_monthly.index, dtype=np.float32)
    yearly_map = {"withdrawal_industrial_m3_year-1": "withdrawal_industrial_monthly", "withdrawal_domestic_m3_year-1": "withdrawal_domestic_monthly"}
    for orig, target in yearly_map.items():
        if orig in grow_id_data.columns:
            series_yearly = grow_id_data[orig].dropna(); series_yearly = series_yearly[~series_yearly.index.duplicated(keep='first')] if not series_yearly.index.is_unique else series_yearly; monthly_features_dict[target] = series_yearly.resample('MS').ffill().reindex(sgi_observed_monthly.index)
        else: monthly_features_dict[target] = pd.Series(index=sgi_observed_monthly.index, dtype=np.float32)
        
    return pd.DataFrame(monthly_features_dict).dropna(subset=['sgi_label'])

# Wende die Funktion auf alle Stations-Gruppen an und zeige einen Fortschrittsbalken
processed_groups = []
for grow_id, group_data in tqdm(grouped_ts_data, desc="SGI-Berechnung & Dekomposition"):
    processed_df = process_grow_id_data(group_data)
    if processed_df is not None and not processed_df.empty: processed_df['GROW_ID'] = grow_id; processed_groups.append(processed_df)
if not processed_groups: raise ValueError("Keine Daten für ML-Modell nach Verarbeitung.")

# --- Schritt 1.5: Finale Datenzusammenführung und Feature-Erstellung ---
print("\n1.5 Führe dynamische und statische Features zusammen...")
df_ml_input_dynamic = pd.concat(processed_groups); del processed_groups; gc.collect()
static_features_to_select = ["GROW_ID"] + STATIC_NUMERICAL_FEATURES + STATIC_CATEGORICAL_FEATURES
static_features_to_select = [col for col in static_features_to_select if col in attr_df_full.columns]
attr_df_ml_static = attr_df_full[attr_df_full['GROW_ID'].isin(cz_ids_for_ml)][static_features_to_select].copy().drop_duplicates(subset=['GROW_ID'], keep='first')
df_ml_input_dynamic.reset_index(inplace=True)
df_ml_input = pd.merge(df_ml_input_dynamic, attr_df_ml_static, on="GROW_ID", how="left").set_index('date')
del df_ml_input_dynamic, attr_df_ml_static, attr_df_full, attr_filtered_df; gc.collect()
df_ml_processed = df_ml_input.copy(); del df_ml_input; gc.collect()

print("\n1.6 Erstelle zeitversetzte (Lag) Features und Zielvariable...")
# Erstelle Lag-Features für die SGI-Komponenten (Werte von vor 1, 3, 6, 12 Monaten)
for lag_col_base in ['sgi_label', 'sgi_trend', 'sgi_seasonal', 'sgi_resid']:
    if lag_col_base in df_ml_processed.columns:
        for lag_val in [1, 3, 6, 12]: df_ml_processed[f'{lag_col_base}_lag_{lag_val}M'] = df_ml_processed.groupby('GROW_ID')[lag_col_base].shift(lag_val)

df_ml_processed['month_num'] = df_ml_processed.index.month.astype(np.int8)
df_ml_processed['year'] = df_ml_processed.index.year.astype(np.int32)

# Erstelle die Zielvariable: der SGI-Wert 6 Monate in der Zukunft
VORHERSAGE_HORIZONT_MONATE = 6
sgi_target_col_continuous = f'sgi_target_{VORHERSAGE_HORIZONT_MONATE}M_future'
df_ml_processed[sgi_target_col_continuous] = df_ml_processed.groupby('GROW_ID')['sgi_label'].shift(-VORHERSAGE_HORIZONT_MONATE)

# --- Schritt 1.7: Zielvariable in Klassen umwandeln und Features vorbereiten ---
print("\n1.7 Wandle Zielvariable in Klassen um und kodiere kategorische Features...")
def sgi_to_drought_class(z_score):
    if pd.isna(z_score): return None
    if z_score > -0.84: return 'Normal'
    if -1.50 <= z_score <= -0.84: return 'Mild_Moderate'
    if -2.00 <= z_score <= -1.51: return 'Severe'
    return 'Extreme'
df_ml_processed['drought_class_str'] = df_ml_processed[sgi_target_col_continuous].apply(sgi_to_drought_class)
class_mapping = {'Normal': 0, 'Mild_Moderate': 1, 'Severe': 2, 'Extreme': 3}
df_ml_processed['drought_class_target'] = df_ml_processed['drought_class_str'].map(class_mapping).astype('Int64')
label_column_ml = 'drought_class_target'

# Definiere die zu kodierenden Spalten dynamisch, basierend auf dem, was wirklich im DataFrame ist
print("\n1.7.1 Kodierung der kategorischen Features...")
categorical_cols_to_encode = [col for col in STATIC_CATEGORICAL_FEATURES if col in df_ml_processed.columns] + ['month_num']
print(f"--> Folgende kategorische Spalten werden kodiert: {categorical_cols_to_encode}")

# Die Schleife bleibt gleich, verarbeitet aber nur existierende Spalten
dummy_encoded_cols_list = []
for col_to_encode in categorical_cols_to_encode:
    print(f"    - Kodiere '{col_to_encode}'...")
    dummies = pd.get_dummies(df_ml_processed[col_to_encode], prefix=col_to_encode, dummy_na=False, dtype=np.int8)
    df_ml_processed = pd.concat([df_ml_processed, dummies], axis=1); df_ml_processed.drop(columns=[col_to_encode], inplace=True)
    dummy_encoded_cols_list.extend(dummies.columns.tolist())

# --- Schritt 1.8: Finale Datenbereinigung ---
print("\n1.8 Bereinige finale Datensätze...")
# Fülle verbleibende Lücken in numerischen Spalten mit dem Median
numerical_static_cols_for_imputation = [col for col in STATIC_NUMERICAL_FEATURES if col in df_ml_processed.columns]
if numerical_static_cols_for_imputation:
    df_ml_processed[numerical_static_cols_for_imputation] = SimpleImputer(strategy='median').fit_transform(df_ml_processed[numerical_static_cols_for_imputation])

# Definiere die finale Liste aller Features für das Modell
base_features_ml = ["precipitation_monthly", "evapotranspiration_monthly", "air_temperature_monthly", "snow_depth_monthly", "ndvi_monthly", "lai_low_veg_monthly", "lai_high_veg_monthly", "withdrawal_industrial_monthly", "withdrawal_domestic_monthly"]
lag_features_ml = [col for col in df_ml_processed.columns if '_lag_' in col]
current_sgi_features = ['sgi_label', 'sgi_trend', 'sgi_seasonal', 'sgi_resid']
features_columns_ml = list(set([col for col in base_features_ml if col in df_ml_processed.columns] + lag_features_ml + current_sgi_features + numerical_static_cols_for_imputation + dummy_encoded_cols_list))
# Entferne Zeilen, in denen wichtige Features oder das Label fehlen
columns_to_check_for_dropna_smart = [label_column_ml, 'sgi_label_lag_1M', 'precipitation_monthly']
df_ml_processed.dropna(subset=[col for col in columns_to_check_for_dropna_smart if col in df_ml_processed.columns], inplace=True)
df_ml_processed[label_column_ml] = df_ml_processed[label_column_ml].astype(int)

# Finale Aufteilung in X (Features) und y (Zielvariable)
X_all_features_raw = df_ml_processed[features_columns_ml].copy()
y_all_labels = df_ml_processed[label_column_ml].copy()
X_meta_for_split = df_ml_processed[['GROW_ID', 'year']].copy()
del df_ml_processed; gc.collect()
print("\n[SUCCESS] Teil 1 & 2 abgeschlossen.")


# --- TEIL 3: MODELLTRAINING UND EVALUATION ---
print("\n" + "="*80); print(" TEIL 3: MODELLTRAINING & EVALUATION (NEURONALES NETZ)"); print("="*80)

# --- Schritt 3.1: Zeitbasierter Train-Validation-Test Split ---
temp_year_series = X_meta_for_split['year']
unique_years_ml = np.sort(temp_year_series.unique())
split_year_1 = int(np.percentile(unique_years_ml, 80))
split_year_2 = int(np.percentile(unique_years_ml, 90))
print(f"--> Erstelle zeitbasierten 80/10/10 Split:")
print(f"    - Trainingsdaten: Jahre < {split_year_1} (80%)")
print(f"    - Validierungsdaten: Jahre >= {split_year_1} und < {split_year_2} (10%)")
print(f"    - Testdaten: Jahre >= {split_year_2} (10%)")
train_mask = temp_year_series < split_year_1
val_mask = (temp_year_series >= split_year_1) & (temp_year_series < split_year_2)
test_mask = temp_year_series >= split_year_2
X_train_raw, X_val_raw, X_test_raw = X_all_features_raw[train_mask], X_all_features_raw[val_mask], X_all_features_raw[test_mask]
y_train, y_val, y_test = y_all_labels[train_mask], y_all_labels[val_mask], y_all_labels[test_mask]
print(f"\nGröße der Datensätze:")
print(f"    - Training:   {X_train_raw.shape[0]} Zeilen")
print(f"    - Validation: {X_val_raw.shape[0]} Zeilen")
print(f"    - Test:       {X_test_raw.shape[0]} Zeilen")
del X_all_features_raw, y_all_labels, X_meta_for_split; gc.collect()


# --- Schritt 3.2: Finale Feature-Übersicht ---
print("\n" + "-"*80)
features_in_model = sorted(X_train_raw.columns.tolist())
print(f"--> Folgende {len(features_in_model)} Features werden für das Modell verwendet:")
print("-" * 80)
max_len = max(len(f) for f in features_in_model) + 2
num_columns = 4
for i in range(0, len(features_in_model), num_columns):
    row = [f"{feat:<{max_len}}" for feat in features_in_model[i:i+num_columns]]
    print("".join(row))
print("-" * 80)


# --- Schritt 3.3: Manuelles Preprocessing der Daten (vor dem NN-Training) ---
print("\n3.3 Führe manuelles Preprocessing durch (Imputer & Scaler)...")
# Imputer zum Füllen fehlender Werte (z.B. mit dem Mittelwert)
imputer = SimpleImputer(strategy='mean')
# Scaler zum Skalieren der Daten (z.B. auf Mittelwert 0 und Standardabweichung 1)
scaler = StandardScaler()

# Daten transformieren: zuerst Imputation, dann Skalierung
X_train_scaled = scaler.fit_transform(imputer.fit_transform(X_train_raw))
X_val_scaled = scaler.transform(imputer.transform(X_val_raw))
X_test_scaled = scaler.transform(imputer.transform(X_test_raw))
print("--> Daten erfolgreich imputiert und skaliert.")


# --- Schritt 3.4: Definition des Keras-Modells (Neuronales Netz) ---
print("\n3.4 Definiere die Architektur des Neuronalen Netzes...")
n_features = X_train_scaled.shape[1] # Anzahl der Eingabefeatures
n_classes = len(class_mapping) # Anzahl der Zielklassen

# Definition des sequentiellen Modells
model = tf.keras.Sequential([
    # Input-Layer: Definiert die Form der Eingabedaten
    tf.keras.layers.Input(shape=(n_features,)),
    # Erste Hidden-Layer: 80 Neuronen, ReLU-Aktivierung, L2-Regularisierung gegen Overfitting
    tf.keras.layers.Dense(
        80, 
        activation='relu',
        kernel_regularizer=tf.keras.regularizers.l2(0.001) 
    ),
    # Dropout-Layer: Deaktiviert zufällig 40% der Neuronen, um Overfitting zu reduzieren
    tf.keras.layers.Dropout(0.4), 
    # Zweite Hidden-Layer: 40 Neuronen, ReLU-Aktivierung, L2-Regularisierung
    tf.keras.layers.Dense(
        40, 
        activation='relu',
        kernel_regularizer=tf.keras.regularizers.l2(0.001) 
    ),
    # Zweiter Dropout-Layer
    tf.keras.layers.Dropout(0.4), 
    # Output-Layer: Anzahl der Neuronen entspricht der Anzahl der Klassen, Softmax für Wahrscheinlichkeiten
    tf.keras.layers.Dense(n_classes, activation='softmax')
])

# Optimierer und Kompilierung des Modells
optimizer = tf.keras.optimizers.Adam(learning_rate=0.005) # Adam-Optimierer mit spezifischer Lernrate
model.compile(optimizer=optimizer,
              loss='sparse_categorical_crossentropy', # Verlustfunktion für Multi-Klassen-Klassifikation
              metrics=['accuracy']) # Metrik zur Überwachung des Trainings

model.summary() # Zeigt eine Zusammenfassung der Modellarchitektur

# --- Schritt 3.5: Definition von Callbacks und Klassengewichten ---
print("\n3.5 Definiere Callbacks und Klassengewichte...")
# ReduceLROnPlateau: Reduziert die Lernrate, wenn der Validierungsverlust stagniert
reduce_lr_callback = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss', factor=0.2, patience=5, min_lr=1e-6, verbose=1
)
# EarlyStopping: Stoppt das Training frühzeitig, wenn der Validierungsverlust nicht mehr sinkt
early_stopping_callback = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=12, restore_best_weights=True 
)

# Berechnung der Klassengewichte, um unausgewogene Klassenverteilungen zu berücksichtigen
class_weights_values = class_weight.compute_class_weight(
    'balanced', classes=np.unique(y_train), y=y_train
)
class_weights_dict = dict(enumerate(class_weights_values))
print(f"--> Verwende Klassengewichte: {class_weights_dict}")

# --- Schritt 3.6: Direktes Training des Modells ---
print("\n3.6 Starte direktes Modelltraining mit model.fit()...")
history = model.fit(
    X_train_scaled, # Trainingsdaten (Features)
    y_train, # Trainingslabels (Zielvariable)
    epochs=200, # Maximale Anzahl der Trainingsepochen
    batch_size=256, # Anzahl der Samples pro Gradienten-Update
    validation_data=(X_val_scaled, y_val), # Validierungsdaten zur Überwachung des Trainingsfortschritts
    callbacks=[early_stopping_callback, reduce_lr_callback], # Callbacks für das Training
    class_weight=class_weights_dict, # Gewichte für die Klassen
    verbose=1 # Zeigt den Fortschritt des Trainings an
)
print("--> Modelltraining abgeschlossen.")


# --- Schritt 3.7: Evaluation des trainierten Modells ---
def evaluate_and_plot_simple(X_data_scaled, y_data, dataset_name, model):
    """Eine Helfer-Funktion zur standardisierten Evaluation und Visualisierung für Neuronale Netze."""
    if X_data_scaled.size == 0 or y_data.empty:
        print(f"\n{dataset_name}-Datensatz ist leer. Evaluation wird übersprungen.")
        return None, None
    print("\n" + "-"*80); print(f" EVALUATION AUF {dataset_name.upper()}-DATEN"); print("-" * 80)
    
    # Mache Vorhersagen
    y_pred_proba = model.predict(X_data_scaled) # Vorhersage der Wahrscheinlichkeiten für jede Klasse
    y_pred = np.argmax(y_pred_proba, axis=1) # Wandelt Wahrscheinlichkeiten in Klassenvorhersagen um
    
    # Gebe den Klassifikations-Report aus
    class_names = list(class_mapping.keys())
    print("\nKlassifikations-Metriken:")
    print(classification_report(y_data, y_pred, labels=range(len(class_names)), target_names=class_names, zero_division=0))
    
    # Plotte die Konfusionsmatrix
    cm = confusion_matrix(y_data, y_pred, labels=range(len(class_names)))
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
    fig, ax = plt.subplots(figsize=(10, 8)); disp.plot(cmap=plt.cm.Blues, ax=ax, xticks_rotation='vertical'); ax.set_title(f'Klassifikationsmatrix für {dataset_name}'); plt.tight_layout(); plt.show()
    
    return y_pred, y_pred_proba

# Führe die Evaluation für Validierungs- und Test-Set durch
y_val_pred, y_val_pred_proba = evaluate_and_plot_simple(X_val_scaled, y_val, "Validation", model)
y_test_pred, y_test_pred_proba = evaluate_and_plot_simple(X_test_scaled, y_test, "Test", model)



# ... (Dein Code bis TEIL 3C bleibt unverändert) ...

print("\n" + "="*80); print(" TEIL 3C: MODELLINTERPRETATION MIT SHAP"); print("="*80)
try:
    # Wichtig: X_val_scaled ist bereits ein NumPy-Array hier.
    # Für SHAP ist es oft besser, wenn es ein Pandas DataFrame ist,
    # um Feature-Namen beizubehalten.
    # X_val_scaled_df wird weiter unten erstellt.

    if X_val_scaled.size > 0: # Prüft, ob Daten vorhanden sind

        # --- Vorbereitung der Daten für SHAP ---
        # Hintergrunddaten für den Explainer
        # `X_train_scaled` ist hier bereits ein NumPy-Array.
        # Konvertiere es zu DataFrame, um Feature-Namen für SHAP zu haben.
        # Wir können `features_in_model` aus Schritt 3.2 verwenden.
        X_train_scaled_df = pd.DataFrame(X_train_scaled, columns=features_in_model)
        X_background = shap.sample(X_train_scaled_df, 100, random_state=42) # Feste random_state für Reproduzierbarkeit

        # Stichprobe der Validierungsdaten für die SHAP-Analyse
        X_val_scaled_df = pd.DataFrame(X_val_scaled, columns=features_in_model)
        X_val_shap_sample_df = shap.sample(X_val_scaled_df, 50, random_state=42) # Feste random_state

        print("\n--> Initialisiere SHAP-Explainer (DeepExplainer wird intern genutzt)...")
        # Für Keras/TensorFlow-Modelle ist shap.Explainer der empfohlene Weg.
        # Er leitet intern zu shap.DeepExplainer weiter, der für NN optimiert ist.
        explainer = shap.Explainer(model, X_background)

        print("\n--> Berechne SHAP-Werte für die Stichprobe der Validierungsdaten (kann einen Moment dauern)...")
        shap_values = explainer(X_val_shap_sample_df) # explainer(DataFrame) gibt ein shap.Explanation Objekt zurück

        # --- DEBUGGING-AUSGABEN HIER BEIBEHALTEN ---
        # shap_values ist hier ein shap.Explanation Objekt.
        # Die tatsächlichen SHAP-Werte sind in shap_values.values
        print(f"DEBUG: SHAP-Werte-Objekt-Typ: {type(shap_values)}")
        if hasattr(shap_values, 'values'):
            actual_shap_values = shap_values.values
            print(f"DEBUG: Typ der tatsächlichen SHAP-Werte: {type(actual_shap_values)}")
            if hasattr(actual_shap_values, 'shape'):
                print(f"DEBUG: Shape der tatsächlichen SHAP-Werte: {actual_shap_values.shape}")
                print(f"DEBUG: Dimensionen der tatsächlichen SHAP-Werte: {actual_shap_values.ndim}")
            # Auch hier kann es eine Liste von Arrays (selten für DeepExplainer) oder ein 3D Array sein
            if isinstance(actual_shap_values, list):
                print(f"DEBUG: tatsächliche SHAP-Werte sind Liste: True, Anzahl der Elemente: {len(actual_shap_values)}")
                if len(actual_shap_values) > 0:
                    if hasattr(actual_shap_values[0], 'shape'):
                        print(f"DEBUG: Shape des ersten Listenelements: {actual_shap_values[0].shape}")
            elif isinstance(actual_shap_values, np.ndarray):
                print(f"DEBUG: tatsächliche SHAP-Werte sind NumPy-Array.")
        # --- ENDE DEBUGGING-AUSGABEN ---

        MAX_SHAP_FEATURES = 40 # Angepasst auf 40, wie bei den Baummodellen

        # --- Globaler SHAP Feature Importance Plot (Bar-Diagramm) ---
        print("\n--> Erstelle SHAP Feature Importance Plot (global)...")
        
        # Die eigentlichen SHAP-Werte sind im .values-Attribut des Explanation-Objekts
        # Diese sind (Samples, Features, Classes) für Multiklassifikation
        if isinstance(shap_values.values, np.ndarray) and shap_values.values.ndim == 3:
            print("INFO: SHAP-Werte sind ein 3D NumPy-Array. Aggregiere für globalen Bar-Plot.")
            # Aggregiere über die Klassenachse (Achse 2)
            shap_values_for_global_plot = np.mean(np.abs(shap_values.values), axis=2) 
            
            # WICHTIG: shap.summary_plot erwartet hier das originale Explanation-Objekt
            # oder ein NumPy-Array, aber die Hintergrunddaten müssen passen.
            # Für den globalen Plot können wir das Explanation-Objekt verwenden,
            # aber nur mit dem Subset der Daten, für das die SHAP-Werte berechnet wurden.
            # Und wir müssen die .values entsprechend manipulieren, bevor wir sie übergeben.
            
            # Die einfachste Art ist, ein neues Explanation-Objekt für den Plot zu erstellen
            # mit den aggregierten Werten, wenn man den Bar-Plot über alle Klassen will.
            # Aber shap.summary_plot(ExplanationObject, plot_type="bar") kann das auch,
            # wenn das ExplanationObject multiklassifiziert ist.
            # Versuchen wir es mit dem rohen Array für den Bar Plot, das hat bei den Bäumen geklappt.
            shap.summary_plot(shap_values_for_global_plot, X_val_shap_sample_df, plot_type="bar", max_display=MAX_SHAP_FEATURES, show=False)
            plt.title("SHAP Feature Importance (Globaler Durchschnitt über alle Klassen) - Neuronales Netz")
            plt.tight_layout()
            plt.show()
            
            # --- SHAP Beeswarm Plots (Detailansicht) für jede Klasse ---
            print("\n--> Erstelle SHAP Beeswarm Plots (Detailansicht) für jede Klasse...")
            # Iterieren über die Klassen-Achse des 3D-Arrays: shap_values.values[:, :, i]
            for i, class_name in enumerate(list(class_mapping.keys())):
                print(f"    - Erstelle Beeswarm Plot für Klasse: '{class_name}' (Index {i}) - Neuronales Netz")
                plt.figure(figsize=(12, 8))
                # shap.summary_plot erwartet hier die SHAP-Werte für die spezifische Klasse (2D Array)
                # und die entsprechenden Hintergrunddaten (X_val_shap_sample_df)
                shap.summary_plot(shap_values.values[:, :, i], X_val_shap_sample_df, max_display=MAX_SHAP_FEATURES, feature_names=features_in_model, show=False)
                plt.title(f"SHAP-Werte für Klasse: '{class_name}' - Neuronales Netz")
                plt.tight_layout()
                plt.show()
                
        elif isinstance(shap_values.values, list) and len(shap_values.values) > 1: # Falls es doch eine Liste von Arrays ist (unwahrscheinlich für DeepExplainer)
            print("INFO: SHAP-Werte sind Liste für Multiklasse. Aggregiere für globalen Bar-Plot.")
            shap_values_for_global_plot = np.mean(np.abs(np.array(shap_values.values)), axis=0) # Hier ist axis=0 korrekt
            
            shap.summary_plot(shap_values_for_global_plot, X_val_shap_sample_df, plot_type="bar", max_display=MAX_SHAP_FEATURES, show=False)
            plt.title("SHAP Feature Importance (Globaler Durchschnitt über alle Klassen) - Neuronales Netz")
            plt.tight_layout()
            plt.show()
            
            # Beeswarm Plots pro Klasse aus der Liste
            print("\n--> Erstelle SHAP Beeswarm Plots (Detailansicht) für jede Klasse...")
            if len(shap_values.values) == len(class_mapping):
                for i, class_name in enumerate(list(class_mapping.keys())):
                    print(f"    - Erstelle Beeswarm Plot für Klasse: '{class_name}' (Index {i}) - Neuronales Netz")
                    plt.figure(figsize=(12, 8))
                    shap.summary_plot(shap_values.values[i], X_val_shap_sample_df, max_display=MAX_SHAP_FEATURES, feature_names=features_in_model, show=False)
                    plt.title(f"SHAP-Werte für Klasse: '{class_name}' - Neuronales Netz")
                    plt.tight_layout()
                    plt.show()
            else:
                print(f"WARNUNG: Anzahl der SHAP-Werte-Listen ({len(shap_values.values)}) stimmt nicht mit der Anzahl der Klassen ({len(class_mapping)}) überein. Überspringe Beeswarm Plots pro Klasse.")
                
        else: # Dies wird ausgeführt, wenn shap_values.values weder 3D Array noch Liste > 1 Element ist
            print("INFO: SHAP-Werte sind kein Multiklassen-Format (oder nur eine Klasse). Erstelle einen einzelnen globalen Beeswarm/Bar-Plot.")
            # Für den globalen Plot bei nur einer Klasse, Beeswarm ist oft aussagekräftiger
            # Hier müssen wir shap_values.values übergeben (das sollte ein 2D-Array sein)
            shap.summary_plot(shap_values.values, X_val_shap_sample_df, max_display=MAX_SHAP_FEATURES, feature_names=features_in_model, show=False)
            plt.title("SHAP-Werte (Gesamt / Binäre Klassifikation) - Neuronales Netz")
            plt.tight_layout()
            plt.show()
            print("WARNUNG: Keine Beeswarm Plots pro Klasse möglich, da SHAP-Werte nicht im Multiklassen-Listenformat vorliegen.")
            
    else:
        print("Validierungsdaten sind leer, SHAP-Analyse wird übersprungen.")
except Exception as e:
    print(f"Fehler bei der Modell-Interpretation: {e}")
    import traceback
    traceback.print_exc()

print("\n[SUCCESS] Teil 3 abgeschlossen.")

# --- TEIL 4: SPEICHERN DER ERGEBNISSE ---
print("\n" + "="*80); print(" TEIL 4: SPEICHERN DER ERGEBNISSE"); print("=" * 80)
if y_test_pred is not None:
    test_results_df = X_test_raw.copy()
    test_results_df[label_column_ml] = y_test
    test_results_df['prediction'] = y_test_pred
    proba_df = pd.DataFrame(y_test_pred_proba, columns=[f'prediction_proba_{cls}' for cls in class_mapping.keys()], index=test_results_df.index)
    test_results_df = pd.concat([test_results_df, proba_df], axis=1)
    
    test_results_df.to_csv("test_data_final_classification_NEURAL_NET.csv", index=True)
    print(f"--> Testdaten mit Vorhersagen und Wahrscheinlichkeiten gespeichert: test_data_final_classification_NEURAL_NET.csv")
else:
    print("--> Testdaten sind leer, keine Speicherung.")

print("\nSkript vollständig abgeschlossen.")
# Out:
# DeprecationWarning: As of Pastas 1.5, no noisemodel is added to the pastas Model class by default anymore. To solve your model using a noisemodel, you have to explicitly add a noisemodel to your model before solving. For more information, and how to adapt your code, please see this issue on GitHub: https://github.com/pastas/pastas/issues/735IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html
# Starte Skript: Stacking-Pipeline (LGBM + Neuronales Netz)
#
# ================================================================================
#  TEIL 1 & 2: DATEN LADEN UND FEATURE ENGINEERING
# ================================================================================
# SGI-Berechnung & Dekomposition: 100%|██████████| 264/264 [00:55<00:00,  4.79it/s]
# [SUCCESS] Teil 1 & 2 abgeschlossen.
#
# ================================================================================
#  TEIL 3: TRAINING MEHRERER MODELLE & FINALES HYBRID
# ================================================================================
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 167
#     165 y_train, y_val, y_test = y_all_labels[train_mask], y_all_labels[val_mask], y_all_labels[test_mask]
#     166 # Für Stacking nutzen wir das kombinierte Trainings- und Validierungsset
# --> 167 X_train_stack = X_all_features_raw[train_val_mask]
#     168 y_train_stack = y_all_labels[train_val_mask]
#     169 print("Daten erfolgreich aufgeteilt.")
#
# NameError: name 'train_val_mask' is not defined
